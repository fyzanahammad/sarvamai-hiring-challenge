# %% [markdown]
# # Task : Semantic Chunking of a Youtube Video

# %% [markdown]
# ## Workflow Steps:
# 1. Download Video and Extract Audio
# 2. Transcription of Audio
# 3. Time-Align Transcript with Audio
# 4. Semantic Chunking of Data
# 5. Evaluation and Judgement Criteria
# 6. Generalization
# 7. Gradio App Interface

# %% [markdown]
# ## 1. Download Video and Extract Audio

# %% [markdown]
# **Explanation of the Requirements:** <br>
# 1. youtube-dl: This library is used for downloading videos from YouTube.<br>
# 2. moviepy: Useful for video and audio processing, such as extracting audio tracks from video files.<br>
# 3. torch and transformers: These libraries are needed if you are using PyTorch-based models like Facebook's Wav2Vec for speech-to-text transcription.<br>
# 4. pandas and numpy: Essential for data manipulation and numerical operations.<br>
# 5. scipy and librosa: Used for more detailed audio analysis and processing tasks.<br>
# 6. soundfile: For reading and writing audio files.<br>
# 7. nltk and spacy: Natural Language Processing libraries useful for text manipulation and processing, especially for the semantic chunking.<br>
# 8. gradio: Allows you to create a web interface to easily interact with your models and processes.<br>

# %%
# %pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting Cython (from -r requirements.txt (line 2))
#   Downloading Cython-3.0.10-cp310-cp310-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from -r requirements.txt (line 3)) (1.22.3)
# Requirement already satisfied: pandas==1.4.2 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from -r requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: scipy==1.7.3 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from -r requirements.txt (line 5)) (1.7.3)
# Requirement already satisfied: pytube in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from -r requirements.txt (line 8)) (15.0.0)
# Requirement already satisfied: youtube-transcript-api in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from -r requirements.txt (line 9)) (0.6.2)
# Requirement already satisfied: moviepy==1.0.3 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from -r requirements.txt (line 10)) (1.0.3)
# Requirement already satisfied: librosa==0.9.1 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from -r requirements.txt (line 11)) (0.9.1)
# Requirement already satisfied: soundfile==0.10.3.post1 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from -r requirements.txt (line 12)) (0.10.3.post1)
# Requirement already satisfied: SpeechRecognition in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from -r requirements.txt (line 15)) (3.10.4)
# Requirement already satisfied: transformers==4.18.0 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from -r requirements.txt (line 16)) (4.18.0)
# Collecting sentencepiece<1.0.0 (from -r requirements.txt (line 18))
#   Downloading sentencepiece-0.2.0-cp310-cp310-win_amd64.whl.metadata (8.3 kB)
# Collecting youtokentome>=1.0.5 (from -r requirements.txt (line 19))
#   Downloading youtokentome-1.0.6.tar.gz (86 kB)
#      ---------------------------------------- 0.0/86.7 kB ? eta -:--:--
#      ---------------------------------------- 86.7/86.7 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [6 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\fyzan\AppData\Local\Temp\pip-install-ebgxt4w8\youtokentome_24307e26fc504dbc9e898b80124a37ab\setup.py", line 5, in <module>
#           from Cython.Build import cythonize
#       ModuleNotFoundError: No module named 'Cython'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %% [markdown]
# ### using youtube_transcript_api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

video_id = 'ysLiABvVos8'
YouTubeTranscriptApi.get_transcript(video_id)
# Out:
# [{'text': 'presents Morning', 'start': 0.24, 'duration': 7.97},
#  {'text': '[Music]', 'start': 2.94, 'duration': 5.27},
#  {'text': 'News good morning I am SRA maaba the',
#   'start': 10.719,
#   'duration': 7.041},
#  {'text': 'headlines campaigning for remaining',
#   'start': 15.64,
#   'duration': 4.719},
#  {'text': 'phases of L SAA elections', 'start': 17.76, 'duration': 5.04},
#  {'text': 'intensifies president dropadi murmu to',
#   'start': 20.359,
#   'duration': 5.121},
#  {'text': 'confir Padma awards at second investure',
#   'start': 22.8,
#   'duration': 6.44},
#  {'text': 'ceremony in raspati bavan today try',
#   'start': 25.48,
#   'duration': 6.08},
#  {'text': 'service conference parivartan chintan',
#   'start': 29.24,
#   'duration': 4.159},
#  {'text': 'chaired by Chief of Defense staff',
#   'start': 31.56,
#   'duration': 4.88},
#  {'text': 'General Anil Chan to be held in New',
#   'start': 33.399,
#   'duration': 6.361},
#  {'text': 'Delhi unrest erupts in Pakistan occupied',
#   'start': 36.44,
#   'duration': 5.84},
#  {'text': 'Kashmir as Pakistan Security Forces',
#   'start': 39.76,
#   'duration': 4.4},
#  {'text': 'deployed ahead of', 'start': 42.28, 'duration': 5.16},
#  {'text': 'protests IMD forast fresh spell of heat',
#   'start': 44.16,
#   'duration': 5.48},
#  {'text': 'wave to continue over Rajasthan and',
#   'start': 47.44,
#   'duration': 5.72},
#  {'text': 'madhi Pradesh and in table tennis monik',
#   'start': 49.64,
#   'duration': 5.64},
#  {'text': 'batra reaches quarterfinals at Saudi',
#   'start': 53.16,
#   'duration': 5.96},
#  {'text': 'Smash in Jada', 'start': 55.28, 'duration': 3.84},
#  {'text': 'and now the news in detail campaigning',
#   'start': 62.0,
#   'duration': 4.6},
#  {'text': 'for the remaining phases of lokha',
#   'start': 64.839,
#   'duration': 4.64},
#  {'text': 'Elections intens has intensified voting',
#   'start': 66.6,
#   'duration': 4.6},
#  {'text': 'in the fourth phase will take place on',
#   'start': 69.479,
#   'duration': 4.521},
#  {'text': 'the 13th of this month in 96 seats',
#   'start': 71.2,
#   'duration': 4.919},
#  {'text': 'spread across 10 states and Union',
#   'start': 74.0,
#   'duration': 4.56},
#  {'text': 'territory as many as', 'start': 76.119, 'duration': 5.0},
#  {'text': '1,717 candidates from 10 states and',
#   'start': 78.56,
#   'duration': 4.28},
#  {'text': 'Union territory are in the freay for',
#   'start': 81.119,
#   'duration': 4.601},
#  {'text': 'this phase in telengana election ring',
#   'start': 82.84,
#   'duration': 4.88},
#  {'text': 'reached its PE in the state with only 3',
#   'start': 85.72,
#   'duration': 3.88},
#  {'text': 'days remaining for the campaigning',
#   'start': 87.72,
#   'duration': 4.439},
#  {'text': 'before for the May 13 polling top',
#   'start': 89.6,
#   'duration': 4.479},
#  {'text': 'leaders of all major parties are making',
#   'start': 92.159,
#   'duration': 4.64},
#  {'text': 'a b line seeking support from electors',
#   'start': 94.079,
#   'duration': 5.481},
#  {'text': 'for their candidates BJP senior leader',
#   'start': 96.799,
#   'duration': 4.36},
#  {'text': 'and Union Minister Amit sha will be',
#   'start': 99.56,
#   'duration': 4.0},
#  {'text': 'taking part in election earing in bonger',
#   'start': 101.159,
#   'duration': 5.0},
#  {'text': 'loksabha constituency later this morning',
#   'start': 103.56,
#   'duration': 4.519},
#  {'text': "he'll be campaigning in support of Party",
#   'start': 106.159,
#   'duration': 5.881},
#  {'text': 'candidate Dr budha naraya G aicc senior',
#   'start': 108.079,
#   'duration': 5.881},
#  {'text': 'leader Rahul Gandhi will take part in',
#   'start': 112.04,
#   'duration': 4.28},
#  {'text': 'election earing in Telangana today and',
#   'start': 113.96,
#   'duration': 4.92},
#  {'text': 'participate in Jan yatra Sabha at',
#   'start': 116.32,
#   'duration': 5.04},
#  {'text': 'narsapur and attend a public meeting at',
#   'start': 118.88,
#   'duration': 4.279},
#  {'text': 'surur nagar on the outskirts of',
#   'start': 121.36,
#   'duration': 4.799},
#  {'text': 'Hyderabad this evening BRS Chief and',
#   'start': 123.159,
#   'duration': 4.801},
#  {'text': 'former Chief Minister K Chandra shikar',
#   'start': 126.159,
#   'duration': 3.841},
#  {'text': 'ra will hold a road show at Karim nagar',
#   'start': 127.96,
#   'duration': 4.52},
#  {'text': 'later today earlier Prime Minister Modi',
#   'start': 130.0,
#   'duration': 4.68},
#  {'text': 'addressed two public meetings yesterday',
#   'start': 132.48,
#   'duration': 4.839},
#  {'text': 'in Karim nagar and waranga loka',
#   'start': 134.68,
#   'duration': 4.68},
#  {'text': 'constituencies Mr Modi said the bond',
#   'start': 137.319,
#   'duration': 4.161},
#  {'text': 'between the Congress and the BRS was',
#   'start': 139.36,
#   'duration': 5.56},
#  {'text': 'Inseparable with regards to corruption',
#   'start': 141.48,
#   'duration': 5.16},
#  {'text': 'he alleged that the parties become a',
#   'start': 144.92,
#   'duration': 3.8},
#  {'text': 'Syndicate behind the screen though they',
#   'start': 146.64,
#   'duration': 5.0},
#  {'text': 'criticize each other in in the open BRS',
#   'start': 148.72,
#   'duration': 4.599},
#  {'text': 'Chief and former Chief Minister K',
#   'start': 151.64,
#   'duration': 4.0},
#  {'text': 'chandrasekhar ra said the BJP was',
#   'start': 153.319,
#   'duration': 4.2},
#  {'text': 'invoking Pakistan for its electoral',
#   'start': 155.64,
#   'duration': 3.959},
#  {'text': 'gains and neglecting real issues',
#   'start': 157.519,
#   'duration': 4.521},
#  {'text': 'concerning the nation addressing people',
#   'start': 159.599,
#   'duration': 5.681},
#  {'text': 'at a road show held at Banu he said the',
#   'start': 162.04,
#   'duration': 4.96},
#  {'text': 'ruling party had also maligned the',
#   'start': 165.28,
#   'duration': 3.76},
#  {'text': 'nation on International platforms',
#   'start': 167.0,
#   'duration': 4.319},
#  {'text': 'through undemocratic decisions like the',
#   'start': 169.04,
#   'duration': 4.08},
#  {'text': 'arrest of Delhi chief minister arind',
#   'start': 171.319,
#   'duration': 4.241},
#  {'text': 'krial apart from targeting whoever',
#   'start': 173.12,
#   'duration': 5.28},
#  {'text': 'opposed it meanwhile BJP leader and',
#   'start': 175.56,
#   'duration': 5.2},
#  {'text': 'Union minister nitin gari said that',
#   'start': 178.4,
#   'duration': 4.64},
#  {'text': 'unwavering public support has helped the',
#   'start': 180.76,
#   'duration': 4.92},
#  {'text': 'BJP in implementing impactful schemes',
#   'start': 183.04,
#   'duration': 5.559},
#  {'text': 'and projects at the center addressing a',
#   'start': 185.68,
#   'duration': 5.16},
#  {'text': 'public meeting in Delhi yesterday in',
#   'start': 188.599,
#   'duration': 4.081},
#  {'text': 'support of BJP candidate from South',
#   'start': 190.84,
#   'duration': 5.16},
#  {'text': 'Delhi loab seat ramir Singh bhuri Mr',
#   'start': 192.68,
#   'duration': 5.72},
#  {'text': 'gari said the union government has spent',
#   'start': 196.0,
#   'duration': 4.44},
#  {'text': 'over 1 lakh CR rupees in various',
#   'start': 198.4,
#   'duration': 4.479},
#  {'text': 'projects over the past 10 years that has',
#   'start': 200.44,
#   'duration': 4.76},
#  {'text': 'transformed Delhi he added that the',
#   'start': 202.879,
#   'duration': 4.121},
#  {'text': 'government has also boosted water supply',
#   'start': 205.2,
#   'duration': 3.84},
#  {'text': 'in the national capital and cleaning of',
#   'start': 207.0,
#   'duration': 4.48},
#  {'text': 'the yamuna river', 'start': 209.04, 'duration': 4.199},
#  {'text': 'in utar Pradesh hectic election', 'start': 211.48, 'duration': 3.8},
#  {'text': 'campaigning is scheduled for today a',
#   'start': 213.239,
#   'duration': 5.161},
#  {'text': 'report to make impeccable strategy for',
#   'start': 215.28,
#   'duration': 5.92},
#  {'text': 'Rial elections senior BJP leader and',
#   'start': 218.4,
#   'duration': 5.32},
#  {'text': 'party president jagat prakash nadda will',
#   'start': 221.2,
#   'duration': 4.239},
#  {'text': 'be in the state capital lakau today',
#   'start': 223.72,
#   'duration': 4.239},
#  {'text': 'evening he will hold meetings of senior',
#   'start': 225.439,
#   'duration': 5.761},
#  {'text': 'party functionaries of lakau unow mallal',
#   'start': 227.959,
#   'duration': 6.241},
#  {'text': 'Gan and rber Loa constituencies he will',
#   'start': 231.2,
#   'duration': 6.599},
#  {'text': 'also hold the meeting of mlas and mlcs',
#   'start': 234.2,
#   'duration': 5.599},
#  {'text': 'of the constituencies which are going',
#   'start': 237.799,
#   'duration': 3.961},
#  {'text': 'for poll in fourth phase of Elections',
#   'start': 239.799,
#   'duration': 3.921},
#  {'text': 'prior to the meeting he will address',
#   'start': 241.76,
#   'duration': 4.36},
#  {'text': 'political rallies in chitra and fatur',
#   'start': 243.72,
#   'duration': 4.32},
#  {'text': 'districts on the other hand samajwadi',
#   'start': 246.12,
#   'duration': 4.199},
#  {'text': 'party Chief akilesh Yad will campaign in',
#   'start': 248.04,
#   'duration': 5.8},
#  {'text': 'bah doraha and lkim Kiri constituencies',
#   'start': 250.319,
#   'duration': 5.441},
#  {'text': 'Congress General Secretary Priyanka',
#   'start': 253.84,
#   'duration': 4.679},
#  {'text': 'Gandhi vadra will also campaign in ryber',
#   'start': 255.76,
#   'duration': 5.28},
#  {'text': 'constituency today suil Chandra tiari',
#   'start': 258.519,
#   'duration': 4.641},
#  {'text': 'akashwani news', 'start': 261.04, 'duration': 4.599},
#  {'text': 'lnno in the fourth phase of Lo saaba',
#   'start': 263.16,
#   'duration': 4.16},
#  {'text': 'elections the nomination process has',
#   'start': 265.639,
#   'duration': 4.56},
#  {'text': 'been completed for 13 seas in ut Pradesh',
#   'start': 267.32,
#   'duration': 4.56},
#  {'text': 'polling on these seats will be held on',
#   'start': 270.199,
#   'duration': 4.0},
#  {'text': 'the 13th of May this also includes the',
#   'start': 271.88,
#   'duration': 4.12},
#  {'text': 'important seat of itava which is',
#   'start': 274.199,
#   'duration': 3.201},
#  {'text': 'considered to be the stronghold of',
#   'start': 276.0,
#   'duration': 4.12},
#  {'text': 'samajwadi party BJP has been winning the',
#   'start': 277.4,
#   'duration': 4.72},
#  {'text': 'seat for the last two loab elections and',
#   'start': 280.12,
#   'duration': 3.519},
#  {'text': 'this time the party has once again',
#   'start': 282.12,
#   'duration': 4.76},
#  {'text': 'nominated sitting MP Ram Shankar Kia as',
#   'start': 283.639,
#   'duration': 6.721},
#  {'text': 'its candidate jitendra do from SP and',
#   'start': 286.88,
#   'duration': 6.039},
#  {'text': 'former hatas MP Sarika Singh bagil from',
#   'start': 290.36,
#   'duration': 5.399},
#  {'text': 'bsp are in the free more from our',
#   'start': 292.919,
#   'duration': 4.601},
#  {'text': 'correspondent five assembly', 'start': 295.759, 'duration': 4.0},
#  {'text': 'constituencies of three districts itawa',
#   'start': 297.52,
#   'duration': 5.2},
#  {'text': 'Ora and kpur dead come under itawa loka',
#   'start': 299.759,
#   'duration': 6.401},
#  {'text': 'seat this include itawa Ora bana dapur',
#   'start': 302.72,
#   'duration': 5.4},
#  {'text': 'and sikandra itawa got political',
#   'start': 306.16,
#   'duration': 3.72},
#  {'text': 'recognition from the late mulam Singh',
#   'start': 308.12,
#   'duration': 3.76},
#  {'text': 'yadov who was the head of the samajwadi',
#   'start': 309.88,
#   'duration': 4.159},
#  {'text': 'party being the largest political family',
#   'start': 311.88,
#   'duration': 4.72},
#  {'text': 'samajwadi party has dominated daawa loka',
#   'start': 314.039,
#   'duration': 4.681},
#  {'text': 'seat SP is the only party to win this',
#   'start': 316.6,
#   'duration': 4.28},
#  {'text': 'seat three times in a row SP had won',
#   'start': 318.72,
#   'duration': 6.16},
#  {'text': 'from here in 1999 2004 and 2009 after',
#   'start': 320.88,
#   'duration': 6.879},
#  {'text': 'that asok D of BJP in 2014 and RAM',
#   'start': 324.88,
#   'duration': 6.08},
#  {'text': 'Shankar karia of BJP in 20 19 become MP',
#   'start': 327.759,
#   'duration': 5.16},
#  {'text': 'from here BJP is trying to score a',
#   'start': 330.96,
#   'duration': 3.64},
#  {'text': 'hattrick of Victory on the seat by',
#   'start': 332.919,
#   'duration': 3.881},
#  {'text': 'making Ram Shankar karia its candidate',
#   'start': 334.6,
#   'duration': 4.599},
#  {'text': 'on the other handp has fielded jitin dor',
#   'start': 336.8,
#   'duration': 4.64},
#  {'text': 'to regain its seat DP candidate and',
#   'start': 339.199,
#   'duration': 4.761},
#  {'text': 'former MP from hatas Sarika Singh Bagel',
#   'start': 341.44,
#   'duration': 4.479},
#  {'text': 'is making the contest interesting all',
#   'start': 343.96,
#   'duration': 3.84},
#  {'text': 'parties have intensified campaing in',
#   'start': 345.919,
#   'duration': 3.801},
#  {'text': 'support of their candidates um aasi',
#   'start': 347.8,
#   'duration': 4.0},
#  {'text': 'akashwani news', 'start': 349.72, 'duration': 5.12},
#  {'text': 'lnno president D mmu will present the',
#   'start': 351.8,
#   'duration': 5.08},
#  {'text': 'Padma awards at the second civil',
#   'start': 354.84,
#   'duration': 4.84},
#  {'text': 'investigator ceremony at raspati bhan in',
#   'start': 356.88,
#   'duration': 5.039},
#  {'text': 'tell you today padm Awards one of the',
#   'start': 359.68,
#   'duration': 4.16},
#  {'text': 'highest highest civilian Awards of the',
#   'start': 361.919,
#   'duration': 3.761},
#  {'text': 'country are conferred in three', 'start': 363.84, 'duration': 5.12},
#  {'text': 'categories padm vibhushan padmabhushan',
#   'start': 365.68,
#   'duration': 5.799},
#  {'text': 'and padmashri the awards are given in',
#   'start': 368.96,
#   'duration': 4.2},
#  {'text': 'various disciplines and Fields of',
#   'start': 371.479,
#   'duration': 4.16},
#  {'text': 'activities including art social work',
#   'start': 373.16,
#   'duration': 4.92},
#  {'text': 'public affairs science and engineering',
#   'start': 375.639,
#   'duration': 5.041},
#  {'text': 'trade and Industry medicine literature',
#   'start': 378.08,
#   'duration': 5.839},
#  {'text': 'and education Sports and Civil Service',
#   'start': 380.68,
#   'duration': 4.72},
#  {'text': 'the awards are announced on the occasion',
#   'start': 383.919,
#   'duration': 4.4},
#  {'text': 'of Republic Day every year last month',
#   'start': 385.4,
#   'duration': 4.84},
#  {'text': 'the president had presented three padm',
#   'start': 388.319,
#   'duration': 5.44},
#  {'text': 'vibhushan eight padmabhushan and 55',
#   'start': 390.24,
#   'duration': 7.0},
#  {'text': 'padmashri Awards on the 22nd of',
#   'start': 393.759,
#   'duration': 5.921},
#  {'text': 'April chief of Defense staff General',
#   'start': 397.24,
#   'duration': 4.32},
#  {'text': 'Anil Chan will chair a two-day', 'start': 399.68, 'duration': 4.4},
#  {'text': 'conference parivartan chintan the second',
#   'start': 401.56,
#   'duration': 4.56},
#  {'text': 'on jointness and integration of armed',
#   'start': 404.08,
#   'duration': 4.72},
#  {'text': 'forces in New Delhi beginning today',
#   'start': 406.12,
#   'duration': 4.519},
#  {'text': 'pararan chintan is a pionering', 'start': 408.8, 'duration': 3.519},
#  {'text': 'conference for the heads of all Tri',
#   'start': 410.639,
#   'duration': 3.96},
#  {'text': 'Services institutes and aims at',
#   'start': 412.319,
#   'duration': 5.0},
#  {'text': 'generating novel reformative ideas and',
#   'start': 414.599,
#   'duration': 5.28},
#  {'text': 'initiatives members from all submit IES',
#   'start': 417.319,
#   'duration': 4.841},
#  {'text': 'of the Apex Chiefs of Staff committee',
#   'start': 419.879,
#   'duration': 4.76},
#  {'text': 'the CDs as its permanent chairman and',
#   'start': 422.16,
#   'duration': 4.24},
#  {'text': 'the three service Chiefs shall review',
#   'start': 424.639,
#   'duration': 4.12},
#  {'text': 'the progress made in multiple domains',
#   'start': 426.4,
#   'duration': 4.68},
#  {'text': 'and ideate on the necessary reforms to',
#   'start': 428.759,
#   'duration': 4.56},
#  {'text': 'achieve the desired end State towards',
#   'start': 431.08,
#   'duration': 5.48},
#  {'text': 'transformation through jointness and',
#   'start': 433.319,
#   'duration': 5.641},
#  {'text': 'integration this is Akash Mari giving',
#   'start': 436.56,
#   'duration': 4.44},
#  {'text': 'you the news for quick news updates',
#   'start': 438.96,
#   'duration': 4.359},
#  {'text': 'Around the Clock follow us on Twitter at',
#   'start': 441.0,
#   'duration': 5.08},
#  {'text': 'a news', 'start': 443.319, 'duration': 2.761},
#  {'text': 'alerts l n 2024 for a special program on',
#   'start': 446.84,
#   'duration': 7.28},
#  {'text': 'the general elections every evening at',
#   'start': 451.44,
#   'duration': 5.84},
#  {'text': '7: and repeat broadcast at 9:30 p.m. on',
#   'start': 454.12,
#   'duration': 6.759},
#  {'text': 'aani gold updates of election activities',
#   'start': 457.28,
#   'duration': 6.639},
#  {'text': 'insights from regions and constituencies',
#   'start': 460.879,
#   'duration': 5.6},
#  {'text': 'expert opinion and Analysis in the',
#   'start': 463.919,
#   'duration': 4.921},
#  {'text': "world's largest Festival of democracy",
#   'start': 466.479,
#   'duration': 5.44},
#  {'text': 'stay tuned', 'start': 468.84, 'duration': 3.079},
#  {'text': 'to', 'start': 472.12, 'duration': 3.0},
#  {'text': '20124 welcome back you listen to Morning',
#   'start': 477.56,
#   'duration': 5.8},
#  {'text': 'News external affairs minister Dr SJ',
#   'start': 480.36,
#   'duration': 5.08},
#  {'text': 'Shanker has said that every political',
#   'start': 483.36,
#   'duration': 3.959},
#  {'text': 'party in the country is committed to',
#   'start': 485.44,
#   'duration': 4.64},
#  {'text': 'ensure that Pakistan occupied Kashmir or',
#   'start': 487.319,
#   'duration': 5.88},
#  {'text': 'P which is a part of India returns to',
#   'start': 490.08,
#   'duration': 5.399},
#  {'text': 'India interacting with the students at',
#   'start': 493.199,
#   'duration': 4.921},
#  {'text': 'gari College in New Delhi Mr J Shanker',
#   'start': 495.479,
#   'duration': 4.921},
#  {'text': 'said the PO issue has come to the front',
#   'start': 498.12,
#   'duration': 4.44},
#  {'text': "of people's thinking after revocation of",
#   'start': 500.4,
#   'duration': 5.0},
#  {'text': 'article 370 in Jammu and Kashmir the',
#   'start': 502.56,
#   'duration': 4.359},
#  {'text': 'minister said that people assumed',
#   'start': 505.4,
#   'duration': 4.12},
#  {'text': 'article 370 could not be changed as the',
#   'start': 506.919,
#   'duration': 4.68},
#  {'text': 'politics of the day had driven it deeply',
#   'start': 509.52,
#   'duration': 4.72},
#  {'text': 'into public', 'start': 511.599, 'duration': 5.961},
#  {'text': 'Consciousness people just assume 370',
#   'start': 514.24,
#   'duration': 5.0},
#  {'text': 'cannot be Chained and that you know this',
#   'start': 517.56,
#   'duration': 3.56},
#  {'text': 'is something we just have to accept',
#   'start': 519.24,
#   'duration': 3.599},
#  {'text': 'because the politics of the day had',
#   'start': 521.12,
#   'duration': 3.64},
#  {'text': 'driven it very deeply into public',
#   'start': 522.839,
#   'duration': 4.361},
#  {'text': 'Consciousness now we see once we change',
#   'start': 524.76,
#   'duration': 4.28},
#  {'text': 'it then the entire ground situation',
#   'start': 527.2,
#   'duration': 4.52},
#  {'text': 'changes so all I can say with respect to',
#   'start': 529.04,
#   'duration': 5.96},
#  {'text': 'PO that there is a parliament resolution',
#   'start': 531.72,
#   'duration': 5.64},
#  {'text': 'every political party of this country is',
#   'start': 535.0,
#   'duration': 4.959},
#  {'text': 'committed to ensure po', 'start': 537.36, 'duration': 5.039},
#  {'text': 'which is a part of India returns to',
#   'start': 539.959,
#   'duration': 5.56},
#  {'text': 'India this actually is our national',
#   'start': 542.399,
#   'duration': 5.361},
#  {'text': 'commitment meanwhile in the wake of the',
#   'start': 545.519,
#   'duration': 4.641},
#  {'text': 'deteriorating economic situation',
#   'start': 547.76,
#   'duration': 4.6},
#  {'text': 'tensions are rising in Pakistan occupied',
#   'start': 550.16,
#   'duration': 5.04},
#  {'text': 'jamu and Kashmir pjk as Pakistan',
#   'start': 552.36,
#   'duration': 4.68},
#  {'text': 'Administration has been deploying troops',
#   'start': 555.2,
#   'duration': 4.16},
#  {'text': 'from Punjab Province to suppress the',
#   'start': 557.04,
#   'duration': 4.239},
#  {'text': 'upcoming protest in the region on',
#   'start': 559.36,
#   'duration': 4.84},
#  {'text': 'Saturday this week according to a joint',
#   'start': 561.279,
#   'duration': 6.041},
#  {'text': 'statement issued by the UK PNP and jaac',
#   'start': 564.2,
#   'duration': 5.319},
#  {'text': 'the demonstrators are protesting and un',
#   'start': 567.32,
#   'duration': 4.92},
#  {'text': 'Justified taxation High electricity',
#   'start': 569.519,
#   'duration': 5.961},
#  {'text': 'bills uncontrolled inflation and severe',
#   'start': 572.24,
#   'duration': 5.96},
#  {'text': 'shortages of Essentials Additionally the',
#   'start': 575.48,
#   'duration': 4.64},
#  {'text': 'people also demand ownership of local',
#   'start': 578.2,
#   'duration': 4.319},
#  {'text': 'land and water resources and royalties',
#   'start': 580.12,
#   'duration': 4.839},
#  {'text': 'to locals over the hydroelectric power',
#   'start': 582.519,
#   'duration': 5.601},
#  {'text': 'produced in dams located in pojk and',
#   'start': 584.959,
#   'duration': 6.281},
#  {'text': 'Pakistan occupied gilid', 'start': 588.12, 'duration': 5.719},
#  {'text': "baltistan India's foreign secretary V",
#   'start': 591.24,
#   'duration': 4.8},
#  {'text': 'moan Katra arrived in Taka on a short',
#   'start': 593.839,
#   'duration': 4.801},
#  {'text': 'trip to Bangladesh yesterday in a social',
#   'start': 596.04,
#   'duration': 4.44},
#  {'text': 'media post Bangladesh foreign Ministry',
#   'start': 598.64,
#   'duration': 4.04},
#  {'text': "shared details about katra's visit",
#   'start': 600.48,
#   'duration': 4.479},
#  {'text': 'saying that he is expected to meet PM sh',
#   'start': 602.68,
#   'duration': 5.04},
#  {'text': 'H foreign minister Hassan mhmood and',
#   'start': 604.959,
#   'duration': 4.161},
#  {'text': 'also h a meeting with the foreign',
#   'start': 607.72,
#   'duration': 3.84},
#  {'text': 'Secretary of Bangladesh masud bin mman',
#   'start': 609.12,
#   'duration': 4.959},
#  {'text': 'today recently in February external',
#   'start': 611.56,
#   'duration': 4.839},
#  {'text': 'affairs minister Dr SJ Shanker extended',
#   'start': 614.079,
#   'duration': 4.161},
#  {'text': 'a warm welcome to Bangladesh foreign',
#   'start': 616.399,
#   'duration': 4.361},
#  {'text': 'minister Hassan mhmood when he arrived',
#   'start': 618.24,
#   'duration': 4.52},
#  {'text': 'in India emphasizing that their',
#   'start': 620.76,
#   'duration': 4.28},
#  {'text': 'discussions aim to fortify the enduring',
#   'start': 622.76,
#   'duration': 7.04},
#  {'text': 'friendship between India and Bangladesh',
#   'start': 625.04,
#   'duration': 7.039},
#  {'text': 'in Punjab wheat harvesting is going on',
#   'start': 629.8,
#   'duration': 4.719},
#  {'text': 'at a rapid Pace the incidents of burning',
#   'start': 632.079,
#   'duration': 4.481},
#  {'text': 'wheat residue left after harvesting are',
#   'start': 634.519,
#   'duration': 4.12},
#  {'text': 'also increasing day by day in various',
#   'start': 636.56,
#   'duration': 4.079},
#  {'text': 'districts due to which the environment',
#   'start': 638.639,
#   'duration': 5.241},
#  {'text': 'is being affected a report the number of',
#   'start': 640.639,
#   'duration': 5.88},
#  {'text': 'incidents of wheat residue being set on',
#   'start': 643.88,
#   'duration': 5.199},
#  {'text': 'fire in fields in various districts of',
#   'start': 646.519,
#   'duration': 4.601},
#  {'text': 'the state has reached', 'start': 649.079, 'duration': 5.281},
#  {'text': '2,612 as of yesterday evening out of it',
#   'start': 651.12,
#   'duration': 6.56},
#  {'text': 'the maximum number of 133 incidents has',
#   'start': 654.36,
#   'duration': 5.44},
#  {'text': 'been reported in the Border District of',
#   'start': 657.68,
#   'duration': 5.2},
#  {'text': 'fur apart from this filka Benda', 'start': 659.8, 'duration': 6.44},
#  {'text': 'gurdaspur Mansa mukar sangrur and Taran',
#   'start': 662.88,
#   'duration': 5.56},
#  {'text': 'Taran are some of the district where the',
#   'start': 666.24,
#   'duration': 4.76},
#  {'text': 'number of these incidents is increasing',
#   'start': 668.44,
#   'duration': 5.32},
#  {'text': 'rapidly however the authorities are also',
#   'start': 671.0,
#   'duration': 5.839},
#  {'text': 'making Farmers aware not to set the fire',
#   'start': 673.76,
#   'duration': 5.759},
#  {'text': 'but despite this these incidents are',
#   'start': 676.839,
#   'duration': 5.0},
#  {'text': 'continuously increasing shishu Sharma',
#   'start': 679.519,
#   'duration': 5.641},
#  {'text': 'Shantel Akash news', 'start': 681.839, 'duration': 6.161},
#  {'text': 'Jalandhar in Kerala many Air India',
#   'start': 685.16,
#   'duration': 4.72},
#  {'text': 'Express flies to the Gulf cooperation',
#   'start': 688.0,
#   'duration': 4.12},
#  {'text': 'Council GCC countries remain cancelled',
#   'start': 689.88,
#   'duration': 4.68},
#  {'text': 'today as well disrupting travel plans of',
#   'start': 692.12,
#   'duration': 5.92},
#  {'text': 'many fights from Kuwait Ras ala Doha',
#   'start': 694.56,
#   'duration': 5.88},
#  {'text': 'musk and sharja to canu International',
#   'start': 698.04,
#   'duration': 4.52},
#  {'text': 'Airport were cancelled by the airline',
#   'start': 700.44,
#   'duration': 3.68},
#  {'text': 'flight services from the airport to',
#   'start': 702.56,
#   'duration': 4.04},
#  {'text': 'sharja mask theom and Abu zabi also',
#   'start': 704.12,
#   'duration': 5.0},
#  {'text': 'stand cancelled airport authorities have',
#   'start': 706.6,
#   'duration': 4.88},
#  {'text': 'asked air travelers to First confirm the',
#   'start': 709.12,
#   'duration': 5.68},
#  {'text': 'flight status before embarking on their',
#   'start': 711.48,
#   'duration': 5.52},
#  {'text': 'Journey the India meteorological',
#   'start': 714.8,
#   'duration': 4.719},
#  {'text': 'Department IMD has forecast a fresh',
#   'start': 717.0,
#   'duration': 4.16},
#  {'text': 'spell of heat wave will continue to',
#   'start': 719.519,
#   'duration': 3.601},
#  {'text': 'Prevail over Rajasthan and madhi Pradesh',
#   'start': 721.16,
#   'duration': 4.44},
#  {'text': 'till tomorrow the IMD said hot and humid',
#   'start': 723.12,
#   'duration': 3.839},
#  {'text': 'weather will prevail over Coastal',
#   'start': 725.6,
#   'duration': 3.64},
#  {'text': 'Gujarat during the next 5 days and over',
#   'start': 726.959,
#   'duration': 4.56},
#  {'text': 'Kerala and Mah till tomorrow the med',
#   'start': 729.24,
#   'duration': 3.719},
#  {'text': 'Department also predicted light to',
#   'start': 731.519,
#   'duration': 3.12},
#  {'text': 'moderate rainfall will fund a storm',
#   'start': 732.959,
#   'duration': 3.68},
#  {'text': 'lightning and squal wins over Northeast',
#   'start': 734.639,
#   'duration': 5.601},
#  {'text': 'India till the 11th of this month onto',
#   'start': 736.639,
#   'duration': 5.56},
#  {'text': 'Sports now star Indian table tennis',
#   'start': 740.24,
#   'duration': 3.839},
#  {'text': 'player manika batra stormed into the',
#   'start': 742.199,
#   'duration': 4.08},
#  {'text': 'quarterfinals of the Saudi Smash in jeda',
#   'start': 744.079,
#   'duration': 4.76},
#  {'text': 'beating world number 14 Nina mham of',
#   'start': 746.279,
#   'duration': 3.401},
#  {'text': 'Germany', 'start': 748.839, 'duration': 2.601},
#  {'text': 'batra defeated middleham to seal her',
#   'start': 749.68,
#   'duration': 4.2},
#  {'text': 'maiden lost 8 entry in the event this is',
#   'start': 751.44,
#   'duration': 4.759},
#  {'text': "batra's first win over middleham in four",
#   'start': 753.88,
#   'duration': 4.36},
#  {'text': 'attempts now the Indian will face',
#   'start': 756.199,
#   'duration': 3.801},
#  {'text': 'another formidable rival world number',
#   'start': 758.24,
#   'duration': 4.32},
#  {'text': 'five hin hayata of Japan for a place in',
#   'start': 760.0,
#   'duration': 5.399},
#  {'text': 'the semi-finals today and an IP Cricket',
#   'start': 762.56,
#   'duration': 4.8},
#  {'text': 'Sun risers Hyderabad defeated LNO super',
#   'start': 765.399,
#   'duration': 3.921},
#  {'text': 'joints by 10 wickets at the Rajiv Gandhi',
#   'start': 767.36,
#   'duration': 3.719},
#  {'text': 'International stadium in Hyderabad last',
#   'start': 769.32,
#   'duration': 3.68},
#  {'text': 'night today Punjab Kings will take on',
#   'start': 771.079,
#   'duration': 3.721},
#  {'text': 'Royal Challengers Bengaluru at Himachal',
#   'start': 773.0,
#   'duration': 4.04},
#  {'text': 'Pradesh Cricket Association stadium in',
#   'start': 774.8,
#   'duration': 4.8},
#  {'text': "dharmshala and now for a look at today's",
#   'start': 777.04,
#   'duration': 5.239},
#  {'text': "newspapers it's over to Ru kataria thank",
#   'start': 779.6,
#   'duration': 5.359},
#  {'text': 'you SRA war of words continue between',
#   'start': 782.279,
#   'duration': 5.081},
#  {'text': 'contesting parties in the loksabha polls',
#   'start': 784.959,
#   'duration': 4.88},
#  {'text': 'Modi targets Congress in Amani adani',
#   'start': 787.36,
#   'duration': 5.0},
#  {'text': 'twist writes Hindustan times while',
#   'start': 789.839,
#   'duration': 4.921},
#  {'text': 'business standard headlines why silent',
#   'start': 792.36,
#   'duration': 6.0},
#  {'text': 'on Amani adani PM J at Rahul the Hindu',
#   'start': 794.76,
#   'duration': 6.079},
#  {'text': "writes after modi's adani Taun Rahul",
#   'start': 798.36,
#   'duration': 5.8},
#  {'text': 'says PM is scared the Asian age report',
#   'start': 800.839,
#   'duration': 5.601},
#  {'text': "Supreme Court to deliver kajal's interim",
#   'start': 804.16,
#   'duration': 5.799},
#  {'text': 'bail order on Friday asra an recalls',
#   'start': 806.44,
#   'duration': 6.079},
#  {'text': 'covid vaccine amid side effect storm',
#   'start': 809.959,
#   'duration': 5.161},
#  {'text': 'says the Pioneer pull down harana',
#   'start': 812.519,
#   'duration': 5.44},
#  {'text': "government bjp's ex Ally urges Congress",
#   'start': 815.12,
#   'duration': 6.159},
#  {'text': 'writes Hindustan times crew on M leave',
#   'start': 817.959,
#   'duration': 5.761},
#  {'text': '90 aenda Express flights grounded',
#   'start': 821.279,
#   'duration': 4.281},
#  {'text': 'reports the Tribune while Hindustan',
#   'start': 823.72,
#   'duration': 3.799},
#  {'text': 'times also carries a picture of',
#   'start': 825.56,
#   'duration': 4.44},
#  {'text': 'passengers waiting at airports after',
#   'start': 827.519,
#   'duration': 5.201},
#  {'text': 'cancellations disrupted flight schedules',
#   'start': 830.0,
#   'duration': 5.199},
#  {'text': 'India Canada Ties on boil again over',
#   'start': 832.72,
#   'duration': 4.799},
#  {'text': "Niner's death writes the Asian age and",
#   'start': 835.199,
#   'duration': 4.281},
#  {'text': 'finally with the move to towards a',
#   'start': 837.519,
#   'duration': 4.0},
#  {'text': 'cashless Society the economic Times and',
#   'start': 839.48,
#   'duration': 4.24},
#  {'text': 'forms e- payment riches leave',
#   'start': 841.519,
#   'duration': 4.601},
#  {'text': 'circulation of currency poorer and with',
#   'start': 843.72,
#   'duration': 5.08},
#  {'text': "that it's back to you SRA thanks Ru and",
#   'start': 846.12,
#   'duration': 3.88},
#  {'text': 'now before we end the bulletin the',
#   'start': 848.8,
#   'duration': 3.719},
#  {'text': 'headlines once again campaigning for',
#   'start': 850.0,
#   'duration': 4.6},
#  {'text': 'remaining phases of Loa elections',
#   'start': 852.519,
#   'duration': 4.68},
#  {'text': 'intensifies president murmu to confer PM',
#   'start': 854.6,
#   'duration': 4.84},
#  {'text': 'awards at second investure ceremony in',
#   'start': 857.199,
#   'duration': 4.681},
#  {'text': 'rashti bavan today Tri service', 'start': 859.44, 'duration': 4.44},
#  {'text': 'conference parivartan chinan chaired by',
#   'start': 861.88,
#   'duration': 4.079},
#  {'text': 'Chief of Defense staff General anel Chan',
#   'start': 863.88,
#   'duration': 4.84},
#  {'text': 'to be held in New Delhi unrest erupts in',
#   'start': 865.959,
#   'duration': 4.761},
#  {'text': 'Pakistan occupied Kashmir as Pakistan',
#   'start': 868.72,
#   'duration': 3.799},
#  {'text': 'Security Forces deployed ahead of',
#   'start': 870.72,
#   'duration': 5.119},
#  {'text': 'protest IMD forast forecast fresh spell',
#   'start': 872.519,
#   'duration': 5.24},
#  {'text': 'of heat wave to continue over Rajasthan',
#   'start': 875.839,
#   'duration': 4.12},
#  {'text': 'and madhi Pradesh and in table tennis',
#   'start': 877.759,
#   'duration': 4.041},
#  {'text': 'manika batra reaches quarterfinals at',
#   'start': 879.959,
#   'duration': 4.481},
#  {'text': 'Southeast Smash in Jada and with that we',
#   'start': 881.8,
#   'duration': 7.64},
#  {'text': 'end the Morning News have a great day',
#   'start': 884.44,
#   'duration': 5.0}]

# %%
from youtube_transcript_api import YouTubeTranscriptApi

def get_video_id_from_url(url):
    # This function extracts the video ID from the YouTube URL
    if "youtube.com/watch?v=" in url:
        return url.split("watch?v=")[1]
    else:
        raise ValueError("Invalid YouTube URL")

def get_transcript(youtube_url):
    try:
        # Extract the video ID from the URL
        video_id = get_video_id_from_url(youtube_url)

        # Fetch the available transcripts
        transcript = YouTubeTranscriptApi.get_transcript(video_id)
        
        # Print each entry of the transcript
        for entry in transcript:
            print(f"Start: {entry['start']} - Duration: {entry['duration']}s")
            print(entry['text'] + '\n')
    
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
get_transcript('https://www.youtube.com/watch?v=ysLiABvVos8')  # Replace with the actual YouTube URL
# Out:
# Start: 0.24 - Duration: 7.97s
# presents Morning
#
# Start: 2.94 - Duration: 5.27s
# [Music]
#
# Start: 10.719 - Duration: 7.041s
# News good morning I am SRA maaba the
#
# Start: 15.64 - Duration: 4.719s
# headlines campaigning for remaining
#
# Start: 17.76 - Duration: 5.04s
# phases of L SAA elections
#
# Start: 20.359 - Duration: 5.121s
# intensifies president dropadi murmu to
#
# Start: 22.8 - Duration: 6.44s
# confir Padma awards at second investure
#
# Start: 25.48 - Duration: 6.08s
# ceremony in raspati bavan today try
#
# Start: 29.24 - Duration: 4.159s
# service conference parivartan chintan
#
# Start: 31.56 - Duration: 4.88s
# chaired by Chief of Defense staff
#
# Start: 33.399 - Duration: 6.361s
# General Anil Chan to be held in New
#
# Start: 36.44 - Duration: 5.84s
# Delhi unrest erupts in Pakistan occupied
#
# Start: 39.76 - Duration: 4.4s
# Kashmir as Pakistan Security Forces
#
# Start: 42.28 - Duration: 5.16s
# deployed ahead of
#
# Start: 44.16 - Duration: 5.48s
# protests IMD forast fresh spell of heat
#
# Start: 47.44 - Duration: 5.72s
# wave to continue over Rajasthan and
#
# Start: 49.64 - Duration: 5.64s
# madhi Pradesh and in table tennis monik
#
# Start: 53.16 - Duration: 5.96s
# batra reaches quarterfinals at Saudi
#
# Start: 55.28 - Duration: 3.84s
# Smash in Jada
#
# Start: 62.0 - Duration: 4.6s
# and now the news in detail campaigning
#
# Start: 64.839 - Duration: 4.64s
# for the remaining phases of lokha
#
# Start: 66.6 - Duration: 4.6s
# Elections intens has intensified voting
#
# Start: 69.479 - Duration: 4.521s
# in the fourth phase will take place on
#
# Start: 71.2 - Duration: 4.919s
# the 13th of this month in 96 seats
#
# Start: 74.0 - Duration: 4.56s
# spread across 10 states and Union
#
# Start: 76.119 - Duration: 5.0s
# territory as many as
#
# Start: 78.56 - Duration: 4.28s
# 1,717 candidates from 10 states and
#
# Start: 81.119 - Duration: 4.601s
# Union territory are in the freay for
#
# Start: 82.84 - Duration: 4.88s
# this phase in telengana election ring
#
# Start: 85.72 - Duration: 3.88s
# reached its PE in the state with only 3
#
# Start: 87.72 - Duration: 4.439s
# days remaining for the campaigning
#
# Start: 89.6 - Duration: 4.479s
# before for the May 13 polling top
#
# Start: 92.159 - Duration: 4.64s
# leaders of all major parties are making
#
# Start: 94.079 - Duration: 5.481s
# a b line seeking support from electors
#
# Start: 96.799 - Duration: 4.36s
# for their candidates BJP senior leader
#
# Start: 99.56 - Duration: 4.0s
# and Union Minister Amit sha will be
#
# Start: 101.159 - Duration: 5.0s
# taking part in election earing in bonger
#
# Start: 103.56 - Duration: 4.519s
# loksabha constituency later this morning
#
# Start: 106.159 - Duration: 5.881s
# he'll be campaigning in support of Party
#
# Start: 108.079 - Duration: 5.881s
# candidate Dr budha naraya G aicc senior
#
# Start: 112.04 - Duration: 4.28s
# leader Rahul Gandhi will take part in
#
# Start: 113.96 - Duration: 4.92s
# election earing in Telangana today and
#
# Start: 116.32 - Duration: 5.04s
# participate in Jan yatra Sabha at
#
# Start: 118.88 - Duration: 4.279s
# narsapur and attend a public meeting at
#
# Start: 121.36 - Duration: 4.799s
# surur nagar on the outskirts of
#
# Start: 123.159 - Duration: 4.801s
# Hyderabad this evening BRS Chief and
#
# Start: 126.159 - Duration: 3.841s
# former Chief Minister K Chandra shikar
#
# Start: 127.96 - Duration: 4.52s
# ra will hold a road show at Karim nagar
#
# Start: 130.0 - Duration: 4.68s
# later today earlier Prime Minister Modi
#
# Start: 132.48 - Duration: 4.839s
# addressed two public meetings yesterday
#
# Start: 134.68 - Duration: 4.68s
# in Karim nagar and waranga loka
#
# Start: 137.319 - Duration: 4.161s
# constituencies Mr Modi said the bond
#
# Start: 139.36 - Duration: 5.56s
# between the Congress and the BRS was
#
# Start: 141.48 - Duration: 5.16s
# Inseparable with regards to corruption
#
# Start: 144.92 - Duration: 3.8s
# he alleged that the parties become a
#
# Start: 146.64 - Duration: 5.0s
# Syndicate behind the screen though they
#
# Start: 148.72 - Duration: 4.599s
# criticize each other in in the open BRS
#
# Start: 151.64 - Duration: 4.0s
# Chief and former Chief Minister K
#
# Start: 153.319 - Duration: 4.2s
# chandrasekhar ra said the BJP was
#
# Start: 155.64 - Duration: 3.959s
# invoking Pakistan for its electoral
#
# Start: 157.519 - Duration: 4.521s
# gains and neglecting real issues
#
# Start: 159.599 - Duration: 5.681s
# concerning the nation addressing people
#
# Start: 162.04 - Duration: 4.96s
# at a road show held at Banu he said the
#
# Start: 165.28 - Duration: 3.76s
# ruling party had also maligned the
#
# Start: 167.0 - Duration: 4.319s
# nation on International platforms
#
# Start: 169.04 - Duration: 4.08s
# through undemocratic decisions like the
#
# Start: 171.319 - Duration: 4.241s
# arrest of Delhi chief minister arind
#
# Start: 173.12 - Duration: 5.28s
# krial apart from targeting whoever
#
# Start: 175.56 - Duration: 5.2s
# opposed it meanwhile BJP leader and
#
# Start: 178.4 - Duration: 4.64s
# Union minister nitin gari said that
#
# Start: 180.76 - Duration: 4.92s
# unwavering public support has helped the
#
# Start: 183.04 - Duration: 5.559s
# BJP in implementing impactful schemes
#
# Start: 185.68 - Duration: 5.16s
# and projects at the center addressing a
#
# Start: 188.599 - Duration: 4.081s
# public meeting in Delhi yesterday in
#
# Start: 190.84 - Duration: 5.16s
# support of BJP candidate from South
#
# Start: 192.68 - Duration: 5.72s
# Delhi loab seat ramir Singh bhuri Mr
#
# Start: 196.0 - Duration: 4.44s
# gari said the union government has spent
#
# Start: 198.4 - Duration: 4.479s
# over 1 lakh CR rupees in various
#
# Start: 200.44 - Duration: 4.76s
# projects over the past 10 years that has
#
# Start: 202.879 - Duration: 4.121s
# transformed Delhi he added that the
#
# Start: 205.2 - Duration: 3.84s
# government has also boosted water supply
#
# Start: 207.0 - Duration: 4.48s
# in the national capital and cleaning of
#
# Start: 209.04 - Duration: 4.199s
# the yamuna river
#
# Start: 211.48 - Duration: 3.8s
# in utar Pradesh hectic election
#
# Start: 213.239 - Duration: 5.161s
# campaigning is scheduled for today a
#
# Start: 215.28 - Duration: 5.92s
# report to make impeccable strategy for
#
# Start: 218.4 - Duration: 5.32s
# Rial elections senior BJP leader and
#
# Start: 221.2 - Duration: 4.239s
# party president jagat prakash nadda will
#
# Start: 223.72 - Duration: 4.239s
# be in the state capital lakau today
#
# Start: 225.439 - Duration: 5.761s
# evening he will hold meetings of senior
#
# Start: 227.959 - Duration: 6.241s
# party functionaries of lakau unow mallal
#
# Start: 231.2 - Duration: 6.599s
# Gan and rber Loa constituencies he will
#
# Start: 234.2 - Duration: 5.599s
# also hold the meeting of mlas and mlcs
#
# Start: 237.799 - Duration: 3.961s
# of the constituencies which are going
#
# Start: 239.799 - Duration: 3.921s
# for poll in fourth phase of Elections
#
# Start: 241.76 - Duration: 4.36s
# prior to the meeting he will address
#
# Start: 243.72 - Duration: 4.32s
# political rallies in chitra and fatur
#
# Start: 246.12 - Duration: 4.199s
# districts on the other hand samajwadi
#
# Start: 248.04 - Duration: 5.8s
# party Chief akilesh Yad will campaign in
#
# Start: 250.319 - Duration: 5.441s
# bah doraha and lkim Kiri constituencies
#
# Start: 253.84 - Duration: 4.679s
# Congress General Secretary Priyanka
#
# Start: 255.76 - Duration: 5.28s
# Gandhi vadra will also campaign in ryber
#
# Start: 258.519 - Duration: 4.641s
# constituency today suil Chandra tiari
#
# Start: 261.04 - Duration: 4.599s
# akashwani news
#
# Start: 263.16 - Duration: 4.16s
# lnno in the fourth phase of Lo saaba
#
# Start: 265.639 - Duration: 4.56s
# elections the nomination process has
#
# Start: 267.32 - Duration: 4.56s
# been completed for 13 seas in ut Pradesh
#
# Start: 270.199 - Duration: 4.0s
# polling on these seats will be held on
#
# Start: 271.88 - Duration: 4.12s
# the 13th of May this also includes the
#
# Start: 274.199 - Duration: 3.201s
# important seat of itava which is
#
# Start: 276.0 - Duration: 4.12s
# considered to be the stronghold of
#
# Start: 277.4 - Duration: 4.72s
# samajwadi party BJP has been winning the
#
# Start: 280.12 - Duration: 3.519s
# seat for the last two loab elections and
#
# Start: 282.12 - Duration: 4.76s
# this time the party has once again
#
# Start: 283.639 - Duration: 6.721s
# nominated sitting MP Ram Shankar Kia as
#
# Start: 286.88 - Duration: 6.039s
# its candidate jitendra do from SP and
#
# Start: 290.36 - Duration: 5.399s
# former hatas MP Sarika Singh bagil from
#
# Start: 292.919 - Duration: 4.601s
# bsp are in the free more from our
#
# Start: 295.759 - Duration: 4.0s
# correspondent five assembly
#
# Start: 297.52 - Duration: 5.2s
# constituencies of three districts itawa
#
# Start: 299.759 - Duration: 6.401s
# Ora and kpur dead come under itawa loka
#
# Start: 302.72 - Duration: 5.4s
# seat this include itawa Ora bana dapur
#
# Start: 306.16 - Duration: 3.72s
# and sikandra itawa got political
#
# Start: 308.12 - Duration: 3.76s
# recognition from the late mulam Singh
#
# Start: 309.88 - Duration: 4.159s
# yadov who was the head of the samajwadi
#
# Start: 311.88 - Duration: 4.72s
# party being the largest political family
#
# Start: 314.039 - Duration: 4.681s
# samajwadi party has dominated daawa loka
#
# Start: 316.6 - Duration: 4.28s
# seat SP is the only party to win this
#
# Start: 318.72 - Duration: 6.16s
# seat three times in a row SP had won
#
# Start: 320.88 - Duration: 6.879s
# from here in 1999 2004 and 2009 after
#
# Start: 324.88 - Duration: 6.08s
# that asok D of BJP in 2014 and RAM
#
# Start: 327.759 - Duration: 5.16s
# Shankar karia of BJP in 20 19 become MP
#
# Start: 330.96 - Duration: 3.64s
# from here BJP is trying to score a
#
# Start: 332.919 - Duration: 3.881s
# hattrick of Victory on the seat by
#
# Start: 334.6 - Duration: 4.599s
# making Ram Shankar karia its candidate
#
# Start: 336.8 - Duration: 4.64s
# on the other handp has fielded jitin dor
#
# Start: 339.199 - Duration: 4.761s
# to regain its seat DP candidate and
#
# Start: 341.44 - Duration: 4.479s
# former MP from hatas Sarika Singh Bagel
#
# Start: 343.96 - Duration: 3.84s
# is making the contest interesting all
#
# Start: 345.919 - Duration: 3.801s
# parties have intensified campaing in
#
# Start: 347.8 - Duration: 4.0s
# support of their candidates um aasi
#
# Start: 349.72 - Duration: 5.12s
# akashwani news
#
# Start: 351.8 - Duration: 5.08s
# lnno president D mmu will present the
#
# Start: 354.84 - Duration: 4.84s
# Padma awards at the second civil
#
# Start: 356.88 - Duration: 5.039s
# investigator ceremony at raspati bhan in
#
# Start: 359.68 - Duration: 4.16s
# tell you today padm Awards one of the
#
# Start: 361.919 - Duration: 3.761s
# highest highest civilian Awards of the
#
# Start: 363.84 - Duration: 5.12s
# country are conferred in three
#
# Start: 365.68 - Duration: 5.799s
# categories padm vibhushan padmabhushan
#
# Start: 368.96 - Duration: 4.2s
# and padmashri the awards are given in
#
# Start: 371.479 - Duration: 4.16s
# various disciplines and Fields of
#
# Start: 373.16 - Duration: 4.92s
# activities including art social work
#
# Start: 375.639 - Duration: 5.041s
# public affairs science and engineering
#
# Start: 378.08 - Duration: 5.839s
# trade and Industry medicine literature
#
# Start: 380.68 - Duration: 4.72s
# and education Sports and Civil Service
#
# Start: 383.919 - Duration: 4.4s
# the awards are announced on the occasion
#
# Start: 385.4 - Duration: 4.84s
# of Republic Day every year last month
#
# Start: 388.319 - Duration: 5.44s
# the president had presented three padm
#
# Start: 390.24 - Duration: 7.0s
# vibhushan eight padmabhushan and 55
#
# Start: 393.759 - Duration: 5.921s
# padmashri Awards on the 22nd of
#
# Start: 397.24 - Duration: 4.32s
# April chief of Defense staff General
#
# Start: 399.68 - Duration: 4.4s
# Anil Chan will chair a two-day
#
# Start: 401.56 - Duration: 4.56s
# conference parivartan chintan the second
#
# Start: 404.08 - Duration: 4.72s
# on jointness and integration of armed
#
# Start: 406.12 - Duration: 4.519s
# forces in New Delhi beginning today
#
# Start: 408.8 - Duration: 3.519s
# pararan chintan is a pionering
#
# Start: 410.639 - Duration: 3.96s
# conference for the heads of all Tri
#
# Start: 412.319 - Duration: 5.0s
# Services institutes and aims at
#
# Start: 414.599 - Duration: 5.28s
# generating novel reformative ideas and
#
# Start: 417.319 - Duration: 4.841s
# initiatives members from all submit IES
#
# Start: 419.879 - Duration: 4.76s
# of the Apex Chiefs of Staff committee
#
# Start: 422.16 - Duration: 4.24s
# the CDs as its permanent chairman and
#
# Start: 424.639 - Duration: 4.12s
# the three service Chiefs shall review
#
# Start: 426.4 - Duration: 4.68s
# the progress made in multiple domains
#
# Start: 428.759 - Duration: 4.56s
# and ideate on the necessary reforms to
#
# Start: 431.08 - Duration: 5.48s
# achieve the desired end State towards
#
# Start: 433.319 - Duration: 5.641s
# transformation through jointness and
#
# Start: 436.56 - Duration: 4.44s
# integration this is Akash Mari giving
#
# Start: 438.96 - Duration: 4.359s
# you the news for quick news updates
#
# Start: 441.0 - Duration: 5.08s
# Around the Clock follow us on Twitter at
#
# Start: 443.319 - Duration: 2.761s
# a news
#
# Start: 446.84 - Duration: 7.28s
# alerts l n 2024 for a special program on
#
# Start: 451.44 - Duration: 5.84s
# the general elections every evening at
#
# Start: 454.12 - Duration: 6.759s
# 7: and repeat broadcast at 9:30 p.m. on
#
# Start: 457.28 - Duration: 6.639s
# aani gold updates of election activities
#
# Start: 460.879 - Duration: 5.6s
# insights from regions and constituencies
#
# Start: 463.919 - Duration: 4.921s
# expert opinion and Analysis in the
#
# Start: 466.479 - Duration: 5.44s
# world's largest Festival of democracy
#
# Start: 468.84 - Duration: 3.079s
# stay tuned
#
# Start: 472.12 - Duration: 3.0s
# to
#
# Start: 477.56 - Duration: 5.8s
# 20124 welcome back you listen to Morning
#
# Start: 480.36 - Duration: 5.08s
# News external affairs minister Dr SJ
#
# Start: 483.36 - Duration: 3.959s
# Shanker has said that every political
#
# Start: 485.44 - Duration: 4.64s
# party in the country is committed to
#
# Start: 487.319 - Duration: 5.88s
# ensure that Pakistan occupied Kashmir or
#
# Start: 490.08 - Duration: 5.399s
# P which is a part of India returns to
#
# Start: 493.199 - Duration: 4.921s
# India interacting with the students at
#
# Start: 495.479 - Duration: 4.921s
# gari College in New Delhi Mr J Shanker
#
# Start: 498.12 - Duration: 4.44s
# said the PO issue has come to the front
#
# Start: 500.4 - Duration: 5.0s
# of people's thinking after revocation of
#
# Start: 502.56 - Duration: 4.359s
# article 370 in Jammu and Kashmir the
#
# Start: 505.4 - Duration: 4.12s
# minister said that people assumed
#
# Start: 506.919 - Duration: 4.68s
# article 370 could not be changed as the
#
# Start: 509.52 - Duration: 4.72s
# politics of the day had driven it deeply
#
# Start: 511.599 - Duration: 5.961s
# into public
#
# Start: 514.24 - Duration: 5.0s
# Consciousness people just assume 370
#
# Start: 517.56 - Duration: 3.56s
# cannot be Chained and that you know this
#
# Start: 519.24 - Duration: 3.599s
# is something we just have to accept
#
# Start: 521.12 - Duration: 3.64s
# because the politics of the day had
#
# Start: 522.839 - Duration: 4.361s
# driven it very deeply into public
#
# Start: 524.76 - Duration: 4.28s
# Consciousness now we see once we change
#
# Start: 527.2 - Duration: 4.52s
# it then the entire ground situation
#
# Start: 529.04 - Duration: 5.96s
# changes so all I can say with respect to
#
# Start: 531.72 - Duration: 5.64s
# PO that there is a parliament resolution
#
# Start: 535.0 - Duration: 4.959s
# every political party of this country is
#
# Start: 537.36 - Duration: 5.039s
# committed to ensure po
#
# Start: 539.959 - Duration: 5.56s
# which is a part of India returns to
#
# Start: 542.399 - Duration: 5.361s
# India this actually is our national
#
# Start: 545.519 - Duration: 4.641s
# commitment meanwhile in the wake of the
#
# Start: 547.76 - Duration: 4.6s
# deteriorating economic situation
#
# Start: 550.16 - Duration: 5.04s
# tensions are rising in Pakistan occupied
#
# Start: 552.36 - Duration: 4.68s
# jamu and Kashmir pjk as Pakistan
#
# Start: 555.2 - Duration: 4.16s
# Administration has been deploying troops
#
# Start: 557.04 - Duration: 4.239s
# from Punjab Province to suppress the
#
# Start: 559.36 - Duration: 4.84s
# upcoming protest in the region on
#
# Start: 561.279 - Duration: 6.041s
# Saturday this week according to a joint
#
# Start: 564.2 - Duration: 5.319s
# statement issued by the UK PNP and jaac
#
# Start: 567.32 - Duration: 4.92s
# the demonstrators are protesting and un
#
# Start: 569.519 - Duration: 5.961s
# Justified taxation High electricity
#
# Start: 572.24 - Duration: 5.96s
# bills uncontrolled inflation and severe
#
# Start: 575.48 - Duration: 4.64s
# shortages of Essentials Additionally the
#
# Start: 578.2 - Duration: 4.319s
# people also demand ownership of local
#
# Start: 580.12 - Duration: 4.839s
# land and water resources and royalties
#
# Start: 582.519 - Duration: 5.601s
# to locals over the hydroelectric power
#
# Start: 584.959 - Duration: 6.281s
# produced in dams located in pojk and
#
# Start: 588.12 - Duration: 5.719s
# Pakistan occupied gilid
#
# Start: 591.24 - Duration: 4.8s
# baltistan India's foreign secretary V
#
# Start: 593.839 - Duration: 4.801s
# moan Katra arrived in Taka on a short
#
# Start: 596.04 - Duration: 4.44s
# trip to Bangladesh yesterday in a social
#
# Start: 598.64 - Duration: 4.04s
# media post Bangladesh foreign Ministry
#
# Start: 600.48 - Duration: 4.479s
# shared details about katra's visit
#
# Start: 602.68 - Duration: 5.04s
# saying that he is expected to meet PM sh
#
# Start: 604.959 - Duration: 4.161s
# H foreign minister Hassan mhmood and
#
# Start: 607.72 - Duration: 3.84s
# also h a meeting with the foreign
#
# Start: 609.12 - Duration: 4.959s
# Secretary of Bangladesh masud bin mman
#
# Start: 611.56 - Duration: 4.839s
# today recently in February external
#
# Start: 614.079 - Duration: 4.161s
# affairs minister Dr SJ Shanker extended
#
# Start: 616.399 - Duration: 4.361s
# a warm welcome to Bangladesh foreign
#
# Start: 618.24 - Duration: 4.52s
# minister Hassan mhmood when he arrived
#
# Start: 620.76 - Duration: 4.28s
# in India emphasizing that their
#
# Start: 622.76 - Duration: 7.04s
# discussions aim to fortify the enduring
#
# Start: 625.04 - Duration: 7.039s
# friendship between India and Bangladesh
#
# Start: 629.8 - Duration: 4.719s
# in Punjab wheat harvesting is going on
#
# Start: 632.079 - Duration: 4.481s
# at a rapid Pace the incidents of burning
#
# Start: 634.519 - Duration: 4.12s
# wheat residue left after harvesting are
#
# Start: 636.56 - Duration: 4.079s
# also increasing day by day in various
#
# Start: 638.639 - Duration: 5.241s
# districts due to which the environment
#
# Start: 640.639 - Duration: 5.88s
# is being affected a report the number of
#
# Start: 643.88 - Duration: 5.199s
# incidents of wheat residue being set on
#
# Start: 646.519 - Duration: 4.601s
# fire in fields in various districts of
#
# Start: 649.079 - Duration: 5.281s
# the state has reached
#
# Start: 651.12 - Duration: 6.56s
# 2,612 as of yesterday evening out of it
#
# Start: 654.36 - Duration: 5.44s
# the maximum number of 133 incidents has
#
# Start: 657.68 - Duration: 5.2s
# been reported in the Border District of
#
# Start: 659.8 - Duration: 6.44s
# fur apart from this filka Benda
#
# Start: 662.88 - Duration: 5.56s
# gurdaspur Mansa mukar sangrur and Taran
#
# Start: 666.24 - Duration: 4.76s
# Taran are some of the district where the
#
# Start: 668.44 - Duration: 5.32s
# number of these incidents is increasing
#
# Start: 671.0 - Duration: 5.839s
# rapidly however the authorities are also
#
# Start: 673.76 - Duration: 5.759s
# making Farmers aware not to set the fire
#
# Start: 676.839 - Duration: 5.0s
# but despite this these incidents are
#
# Start: 679.519 - Duration: 5.641s
# continuously increasing shishu Sharma
#
# Start: 681.839 - Duration: 6.161s
# Shantel Akash news
#
# Start: 685.16 - Duration: 4.72s
# Jalandhar in Kerala many Air India
#
# Start: 688.0 - Duration: 4.12s
# Express flies to the Gulf cooperation
#
# Start: 689.88 - Duration: 4.68s
# Council GCC countries remain cancelled
#
# Start: 692.12 - Duration: 5.92s
# today as well disrupting travel plans of
#
# Start: 694.56 - Duration: 5.88s
# many fights from Kuwait Ras ala Doha
#
# Start: 698.04 - Duration: 4.52s
# musk and sharja to canu International
#
# Start: 700.44 - Duration: 3.68s
# Airport were cancelled by the airline
#
# Start: 702.56 - Duration: 4.04s
# flight services from the airport to
#
# Start: 704.12 - Duration: 5.0s
# sharja mask theom and Abu zabi also
#
# Start: 706.6 - Duration: 4.88s
# stand cancelled airport authorities have
#
# Start: 709.12 - Duration: 5.68s
# asked air travelers to First confirm the
#
# Start: 711.48 - Duration: 5.52s
# flight status before embarking on their
#
# Start: 714.8 - Duration: 4.719s
# Journey the India meteorological
#
# Start: 717.0 - Duration: 4.16s
# Department IMD has forecast a fresh
#
# Start: 719.519 - Duration: 3.601s
# spell of heat wave will continue to
#
# Start: 721.16 - Duration: 4.44s
# Prevail over Rajasthan and madhi Pradesh
#
# Start: 723.12 - Duration: 3.839s
# till tomorrow the IMD said hot and humid
#
# Start: 725.6 - Duration: 3.64s
# weather will prevail over Coastal
#
# Start: 726.959 - Duration: 4.56s
# Gujarat during the next 5 days and over
#
# Start: 729.24 - Duration: 3.719s
# Kerala and Mah till tomorrow the med
#
# Start: 731.519 - Duration: 3.12s
# Department also predicted light to
#
# Start: 732.959 - Duration: 3.68s
# moderate rainfall will fund a storm
#
# Start: 734.639 - Duration: 5.601s
# lightning and squal wins over Northeast
#
# Start: 736.639 - Duration: 5.56s
# India till the 11th of this month onto
#
# Start: 740.24 - Duration: 3.839s
# Sports now star Indian table tennis
#
# Start: 742.199 - Duration: 4.08s
# player manika batra stormed into the
#
# Start: 744.079 - Duration: 4.76s
# quarterfinals of the Saudi Smash in jeda
#
# Start: 746.279 - Duration: 3.401s
# beating world number 14 Nina mham of
#
# Start: 748.839 - Duration: 2.601s
# Germany
#
# Start: 749.68 - Duration: 4.2s
# batra defeated middleham to seal her
#
# Start: 751.44 - Duration: 4.759s
# maiden lost 8 entry in the event this is
#
# Start: 753.88 - Duration: 4.36s
# batra's first win over middleham in four
#
# Start: 756.199 - Duration: 3.801s
# attempts now the Indian will face
#
# Start: 758.24 - Duration: 4.32s
# another formidable rival world number
#
# Start: 760.0 - Duration: 5.399s
# five hin hayata of Japan for a place in
#
# Start: 762.56 - Duration: 4.8s
# the semi-finals today and an IP Cricket
#
# Start: 765.399 - Duration: 3.921s
# Sun risers Hyderabad defeated LNO super
#
# Start: 767.36 - Duration: 3.719s
# joints by 10 wickets at the Rajiv Gandhi
#
# Start: 769.32 - Duration: 3.68s
# International stadium in Hyderabad last
#
# Start: 771.079 - Duration: 3.721s
# night today Punjab Kings will take on
#
# Start: 773.0 - Duration: 4.04s
# Royal Challengers Bengaluru at Himachal
#
# Start: 774.8 - Duration: 4.8s
# Pradesh Cricket Association stadium in
#
# Start: 777.04 - Duration: 5.239s
# dharmshala and now for a look at today's
#
# Start: 779.6 - Duration: 5.359s
# newspapers it's over to Ru kataria thank
#
# Start: 782.279 - Duration: 5.081s
# you SRA war of words continue between
#
# Start: 784.959 - Duration: 4.88s
# contesting parties in the loksabha polls
#
# Start: 787.36 - Duration: 5.0s
# Modi targets Congress in Amani adani
#
# Start: 789.839 - Duration: 4.921s
# twist writes Hindustan times while
#
# Start: 792.36 - Duration: 6.0s
# business standard headlines why silent
#
# Start: 794.76 - Duration: 6.079s
# on Amani adani PM J at Rahul the Hindu
#
# Start: 798.36 - Duration: 5.8s
# writes after modi's adani Taun Rahul
#
# Start: 800.839 - Duration: 5.601s
# says PM is scared the Asian age report
#
# Start: 804.16 - Duration: 5.799s
# Supreme Court to deliver kajal's interim
#
# Start: 806.44 - Duration: 6.079s
# bail order on Friday asra an recalls
#
# Start: 809.959 - Duration: 5.161s
# covid vaccine amid side effect storm
#
# Start: 812.519 - Duration: 5.44s
# says the Pioneer pull down harana
#
# Start: 815.12 - Duration: 6.159s
# government bjp's ex Ally urges Congress
#
# Start: 817.959 - Duration: 5.761s
# writes Hindustan times crew on M leave
#
# Start: 821.279 - Duration: 4.281s
# 90 aenda Express flights grounded
#
# Start: 823.72 - Duration: 3.799s
# reports the Tribune while Hindustan
#
# Start: 825.56 - Duration: 4.44s
# times also carries a picture of
#
# Start: 827.519 - Duration: 5.201s
# passengers waiting at airports after
#
# Start: 830.0 - Duration: 5.199s
# cancellations disrupted flight schedules
#
# Start: 832.72 - Duration: 4.799s
# India Canada Ties on boil again over
#
# Start: 835.199 - Duration: 4.281s
# Niner's death writes the Asian age and
#
# Start: 837.519 - Duration: 4.0s
# finally with the move to towards a
#
# Start: 839.48 - Duration: 4.24s
# cashless Society the economic Times and
#
# Start: 841.519 - Duration: 4.601s
# forms e- payment riches leave
#
# Start: 843.72 - Duration: 5.08s
# circulation of currency poorer and with
#
# Start: 846.12 - Duration: 3.88s
# that it's back to you SRA thanks Ru and
#
# Start: 848.8 - Duration: 3.719s
# now before we end the bulletin the
#
# Start: 850.0 - Duration: 4.6s
# headlines once again campaigning for
#
# Start: 852.519 - Duration: 4.68s
# remaining phases of Loa elections
#
# Start: 854.6 - Duration: 4.84s
# intensifies president murmu to confer PM
#
# Start: 857.199 - Duration: 4.681s
# awards at second investure ceremony in
#
# Start: 859.44 - Duration: 4.44s
# rashti bavan today Tri service
#
# Start: 861.88 - Duration: 4.079s
# conference parivartan chinan chaired by
#
# Start: 863.88 - Duration: 4.84s
# Chief of Defense staff General anel Chan
#
# Start: 865.959 - Duration: 4.761s
# to be held in New Delhi unrest erupts in
#
# Start: 868.72 - Duration: 3.799s
# Pakistan occupied Kashmir as Pakistan
#
# Start: 870.72 - Duration: 5.119s
# Security Forces deployed ahead of
#
# Start: 872.519 - Duration: 5.24s
# protest IMD forast forecast fresh spell
#
# Start: 875.839 - Duration: 4.12s
# of heat wave to continue over Rajasthan
#
# Start: 877.759 - Duration: 4.041s
# and madhi Pradesh and in table tennis
#
# Start: 879.959 - Duration: 4.481s
# manika batra reaches quarterfinals at
#
# Start: 881.8 - Duration: 7.64s
# Southeast Smash in Jada and with that we
#
# Start: 884.44 - Duration: 5.0s
# end the Morning News have a great day

# %% [markdown]
# ### using pytube

# %%
import os

from pytube import YouTube

# %%
youtube_url = "https://www.youtube.com/watch?v=ysLiABvVos8"

# %%
def rename_audio(file_path):
    # Define the new file name
    new_file_name = "audio_file" + os.path.splitext(file_path)[1]

    # Get the directory of the file
    file_directory = os.path.dirname(file_path)

    # Get the new file path
    new_file_path = os.path.join(file_directory, new_file_name)

    # Rename the file
    os.rename(file_path, new_file_path)

    print(f"Renamed '{file_path}' to '{new_file_path}'")

    return new_file_path

# %%
def download_audio(youtube_url):
    # Create a YouTube object with the URL
    yt = YouTube(youtube_url)

    # Define output directory
    output_path = "downloaded_audio"

    # Get the best audio stream
    audio_stream = yt.streams.get_audio_only()

    # Download the audio stream
    downloaded_file_path = audio_stream.download(output_path)

    # Rename the downloaded audio file
    renamed_file_path = rename_audio(downloaded_file_path)

    print(f"Downloaded '{audio_stream.title}' to '{renamed_file_path}' as '{audio_stream.mime_type}'.")

    return renamed_file_path

# %%
from pytube import YouTube
import os

def download_audio(youtube_url, output_path, file_name):
    # Create a YouTube object with the URL
    yt = YouTube(youtube_url)

    # Get the best audio stream
    audio_stream = yt.streams.get_audio_only()

    # Download the audio stream with the specified file name
    audio_file_path = os.path.join(output_path, file_name)
    audio_stream.download(output_path=output_path, filename=file_name)

    print(f"Downloaded '{audio_stream.title}' to '{audio_file_path}' as '{audio_stream.mime_type}'.")

# %%
# Example usage
download_audio('https://www.youtube.com/watch?v=ysLiABvVos8')
# Out:
# Renamed 'e:\Github_projects\sarvamai-hiring-challenge\downloaded_audio\Campaigning for remaining phases of Lok Sabha elections intensifies.mp4' to 'e:\Github_projects\sarvamai-hiring-challenge\downloaded_audio\audio_file.mp4'
# Downloaded 'Campaigning for remaining phases of Lok Sabha elections intensifies' to 'e:\Github_projects\sarvamai-hiring-challenge\downloaded_audio\audio_file.mp4' as 'audio/mp4'.
# 'e:\\Github_projects\\sarvamai-hiring-challenge\\downloaded_audio\\audio_file.mp4'

# %% [markdown]
# ### .wav file

# %%
import os
import subprocess
from pytube import YouTube

def download_audio(youtube_url):
    # Create a YouTube object with the URL
    yt = YouTube(youtube_url)

    # Define output directory
    output_path = "downloaded_audio"

    # Get the best audio stream
    audio_stream = yt.streams.get_audio_only()

    # Download the audio stream
    downloaded_file_path = audio_stream.download(output_path)

    # Rename the downloaded audio file
    renamed_file_path = rename_audio(downloaded_file_path)

    print(f"Downloaded '{audio_stream.title}' to '{renamed_file_path}' as '{audio_stream.mime_type}'.")

    # Convert to .wav format
    wav_file_path = convert_to_wav(renamed_file_path)

    print(f"Converted '{renamed_file_path}' to '{wav_file_path}'.")

    return wav_file_path

def rename_audio(file_path):
    # Define the new file name
    new_file_name = "audio_file"

    # Get the directory of the file
    file_directory = os.path.dirname(file_path)

    # Get the file extension
    file_extension = os.path.splitext(file_path)[1]

    # Create a unique new file name
    count = 1
    while os.path.exists(os.path.join(file_directory, f"{new_file_name}_{count}{file_extension}")):
        count += 1

    new_file_name = f"{new_file_name}_{count}{file_extension}"
    # Get the new file path
    new_file_path = os.path.join(file_directory, new_file_name)

    # Rename the file
    os.rename(file_path, new_file_path)

    print(f"Renamed '{file_path}' to '{new_file_path}'")

    return new_file_path

def convert_to_wav(file_path):
    # Define output directory
    output_directory = os.path.dirname(file_path)

    # Define the new file name with .wav extension
    wav_file_name = os.path.splitext(os.path.basename(file_path))[0] + ".wav"

    # Define the output path for the converted .wav file
    wav_file_path = os.path.join(output_directory, wav_file_name)

    # Execute FFmpeg command to convert to .wav format
    subprocess.run(["ffmpeg", "-i", file_path, "-acodec", "pcm_s16le", "-ar", "44100", wav_file_path], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    return wav_file_path

# Example usage:
youtube_url = "https://www.youtube.com/watch?v=ysLiABvVos8"
wav_file_path = download_audio(youtube_url)
# Out:
# Renamed 'e:\Github_projects\sarvamai-hiring-challenge\downloaded_audio\Campaigning for remaining phases of Lok Sabha elections intensifies.mp4' to 'e:\Github_projects\sarvamai-hiring-challenge\downloaded_audio\audio_file_1.mp4'
# Downloaded 'Campaigning for remaining phases of Lok Sabha elections intensifies' to 'e:\Github_projects\sarvamai-hiring-challenge\downloaded_audio\audio_file_1.mp4' as 'audio/mp4'.
# Converted 'e:\Github_projects\sarvamai-hiring-challenge\downloaded_audio\audio_file_1.mp4' to 'e:\Github_projects\sarvamai-hiring-challenge\downloaded_audio\audio_file_1.wav'.

# %%
# !ffmpeg -i E:/Github_projects/sarvamai-hiring-challenge/downloaded_audio/audio.mp4 -acodec pcm_s16le -ar 16000 ytaudio.wav
# Out:
# ffmpeg version N-115182-g0d9591841b-20240512 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 13.2.0 (crosstool-NG 1.26.0.65_ecc5e41)
#   configuration: --prefix=/ffbuild/prefix --pkg-config-flags=--static --pkg-config=pkg-config --cross-prefix=x86_64-w64-mingw32- --arch=x86_64 --target-os=mingw32 --enable-gpl --enable-version3 --disable-debug --disable-w32threads --enable-pthreads --enable-iconv --enable-libxml2 --enable-zlib --enable-libfreetype --enable-libfribidi --enable-gmp --enable-fontconfig --enable-libharfbuzz --enable-libvorbis --enable-opencl --disable-libpulse --enable-libvmaf --disable-libxcb --disable-xlib --enable-amf --enable-libaom --enable-libaribb24 --enable-avisynth --enable-chromaprint --enable-libdav1d --enable-libdavs2 --enable-libdvdread --enable-libdvdnav --disable-libfdk-aac --enable-ffnvcodec --enable-cuda-llvm --enable-frei0r --enable-libgme --enable-libkvazaar --enable-libaribcaption --enable-libass --enable-libbluray --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librist --enable-libssh --enable-libtheora --enable-libvpx --enable-libwebp --enable-lv2 --enable-libvpl --enable-openal --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenh264 --enable-libopenjpeg --enable-libopenmpt --enable-librav1e --enable-librubberband --enable-schannel --enable-sdl2 --enable-libsoxr --enable-libsrt --enable-libsvtav1 --enable-libtwolame --enable-libuavs3d --disable-libdrm --enable-vaapi --enable-libvidstab --enable-vulkan --enable-libshaderc --enable-libplacebo --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libzimg --enable-libzvbi --extra-cflags=-DLIBTWOLAME_STATIC --extra-cxxflags= --extra-libs=-lgomp --extra-ldflags=-pthread --extra-ldexeflags= --cc=x86_64-w64-mingw32-gcc --cxx=x86_64-w64-mingw32-g++ --ar=x86_64-w64-mingw32-gcc-ar --ranlib=x86_64-w64-mingw32-gcc-ranlib --nm=x86_64-w64-mingw32-gcc-nm --extra-version=20240512
#   libavutil      59. 17.100 / 59. 17.100
#   libavcodec     61.  5.103 / 61.  5.103
#   libavformat    61.  3.103 / 61.  3.103
#   libavdevice    61.  2.100 / 61.  2.100
#   libavfilter    10.  2.101 / 10.  2.101
#   libswscale      8.  2.100 /  8.  2.100
#   libswresample   5.  2.100 /  5.  2.100
#   libpostproc    58.  2.100 / 58.  2.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'E:/Github_projects/sarvamai-hiring-challenge/downloaded_audio/audio.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     creation_time   : 2024-05-10T09:12:21.000000Z
#     encoder         : Google
#   Duration: 00:14:52.06, start: 0.000000, bitrate: 129 kb/s
#   Stream #0:0[0x1](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         creation_time   : 2024-05-10T09:12:21.000000Z
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ytaudio.wav':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     ISFT            : Lavf61.3.103
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, stereo, s16, 512 kb/s (default)
#       Metadata:
#         creation_time   : 2024-05-10T09:12:21.000000Z
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.5.103 pcm_s16le
# size=   49408KiB time=00:13:11.42 bitrate= 511.4kbits/s speed=1.53e+03x
# [out#0/wav @ 000001fc1bc57d00] video:0KiB audio:55754KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000137%
# size=   55754KiB time=00:14:52.06 bitrate= 512.0kbits/s speed=1.54e+03x

# %% [markdown]
# ### audio to text

# %%
# !pip install --upgrade pip
# !pip install --upgrade git+https://github.com/huggingface/transformers.git accelerate datasets[audio]
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: pip in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (24.0)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to c:\users\fyzan\appdata\local\temp\pip-req-build-wngl1esl
#   Resolved https://github.com/huggingface/transformers.git to commit 37543bad3c1589bfe469e76f896b7fd5e5b1d0e6
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting accelerate
#   Downloading accelerate-0.30.1-py3-none-any.whl.metadata (18 kB)
# Collecting datasets[audio]
#   Downloading datasets-2.19.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from transformers==4.41.0.dev0) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from transformers==4.41.0.dev0) (0.23.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from transformers==4.41.0.dev0) (1.22.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from transformers==4.41.0.dev0) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from transformers==4.41.0.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from transformers==4.41.0.dev0) (2024.5.10)
# Requirement already satisfied: requests in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from transformers==4.41.0.dev0) (2.31.0)
# Collecting tokenizers<0.20,>=0.19 (from transformers==4.41.0.dev0)
#   Downloading tokenizers-0.19.1-cp310-none-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.1 (from transformers==4.41.0.dev0)
#   Downloading safetensors-0.4.3-cp310-none-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from transformers==4.41.0.dev0) (4.66.4)
# Requirement already satisfied: psutil in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from accelerate) (5.9.8)
# Requirement already satisfied: torch>=1.10.0 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from accelerate) (1.12.0)
# Collecting pyarrow>=12.0.0 (from datasets[audio])
#   Downloading pyarrow-16.1.0-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Collecting pyarrow-hotfix (from datasets[audio])
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets[audio])
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from datasets[audio]) (1.4.2)
# Collecting xxhash (from datasets[audio])
#   Downloading xxhash-3.4.1-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets[audio])
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets[audio]) (2024.3.1)
# Requirement already satisfied: aiohttp in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from datasets[audio]) (3.9.5)
# Collecting soundfile>=0.12.1 (from datasets[audio])
#   Downloading soundfile-0.12.1-py2.py3-none-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: librosa in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from datasets[audio]) (0.9.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from aiohttp->datasets[audio]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from aiohttp->datasets[audio]) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from aiohttp->datasets[audio]) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from aiohttp->datasets[audio]) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from aiohttp->datasets[audio]) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from aiohttp->datasets[audio]) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.0.dev0) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from requests->transformers==4.41.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from requests->transformers==4.41.0.dev0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from requests->transformers==4.41.0.dev0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from requests->transformers==4.41.0.dev0) (2024.2.2)
# Requirement already satisfied: cffi>=1.0 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from soundfile>=0.12.1->datasets[audio]) (1.16.0)
# Requirement already satisfied: colorama in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from tqdm>=4.27->transformers==4.41.0.dev0) (0.4.6)
# Requirement already satisfied: audioread>=2.1.5 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from librosa->datasets[audio]) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from librosa->datasets[audio]) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from librosa->datasets[audio]) (1.4.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from librosa->datasets[audio]) (1.4.2)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from librosa->datasets[audio]) (4.4.2)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from librosa->datasets[audio]) (0.4.3)
# Requirement already satisfied: numba>=0.45.1 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from librosa->datasets[audio]) (0.59.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from librosa->datasets[audio]) (1.8.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from pandas->datasets[audio]) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from pandas->datasets[audio]) (2024.1)
# Requirement already satisfied: pycparser in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->datasets[audio]) (2.22)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from numba>=0.45.1->librosa->datasets[audio]) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from pooch>=1.0->librosa->datasets[audio]) (4.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets[audio]) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\fyzan\anaconda3\envs\sarvam\lib\site-packages (from scikit-learn>=0.19.1->librosa->datasets[audio]) (3.5.0)
# Downloading accelerate-0.30.1-py3-none-any.whl (302 kB)
#    ---------------------------------------- 0.0/302.6 kB ? eta -:--:--
#    --------------------------------------- 302.6/302.6 kB 19.5 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ---------------------------------------- 0.0/116.3 kB ? eta -:--:--
#    ---------------------------------------- 116.3/116.3 kB ? eta 0:00:00
# Downloading pyarrow-16.1.0-cp310-cp310-win_amd64.whl (25.9 MB)
#    ---------------------------------------- 0.0/25.9 MB ? eta -:--:--
#     --------------------------------------- 0.6/25.9 MB 13.5 MB/s eta 0:00:02
#    -- ------------------------------------- 1.6/25.9 MB 16.8 MB/s eta 0:00:02
#    --- ------------------------------------ 2.0/25.9 MB 18.4 MB/s eta 0:00:02
#    --- ------------------------------------ 2.0/25.9 MB 18.4 MB/s eta 0:00:02
#    --- ------------------------------------ 2.0/25.9 MB 18.4 MB/s eta 0:00:02
#    --- ------------------------------------ 2.0/25.9 MB 18.4 MB/s eta 0:00:02
#    --- ------------------------------------ 2.0/25.9 MB 18.4 MB/s eta 0:00:02
#    --- ------------------------------------ 2.0/25.9 MB 18.4 MB/s eta 0:00:02
#    --- ------------------------------------ 2.0/25.9 MB 18.4 MB/s eta 0:00:02
#    --- ------------------------------------ 2.0/25.9 MB 18.4 MB/s eta 0:00:02
#    --- ------------------------------------ 2.0/25.9 MB 18.4 MB/s eta 0:00:02
#    --- ------------------------------------ 2.0/25.9 MB 18.4 MB/s eta 0:00:02
#    --- ------------------------------------ 2.0/25.9 MB 18.4 MB/s eta 0:00:02
#    --- ------------------------------------ 2.0/25.9 MB 18.4 MB/s eta 0:00:02
#    --- ------------------------------------ 2.0/25.9 MB 18.4 MB/s eta 0:00:02
#    --- ------------------------------------ 2.0/25.9 MB 18.4 MB/s eta 0:00:02
#    --- ------------------------------------ 2.0/25.9 MB 18.4 MB/s eta 0:00:02
#    --- ------------------------------------ 2.0/25.9 MB 18.4 MB/s eta 0:00:02
#    --- ------------------------------------ 2.3/25.9 MB 2.6 MB/s eta 0:00:09
#    ---- ----------------------------------- 2.8/25.9 MB 3.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 3.3/25.9 MB 3.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 3.8/25.9 MB 3.8 MB/s eta 0:00:06
#    ------ --------------------------------- 4.5/25.9 MB 4.2 MB/s eta 0:00:06
#    ------ --------------------------------- 4.5/25.9 MB 4.2 MB/s eta 0:00:06
#    ------ --------------------------------- 4.5/25.9 MB 4.2 MB/s eta 0:00:06
#    ------ --------------------------------- 4.5/25.9 MB 4.2 MB/s eta 0:00:06
#    ------ --------------------------------- 4.5/25.9 MB 4.2 MB/s eta 0:00:06
#    ------ --------------------------------- 4.5/25.9 MB 4.2 MB/s eta 0:00:06
#    ------ --------------------------------- 4.5/25.9 MB 4.2 MB/s eta 0:00:06
#    ------ --------------------------------- 4.5/25.9 MB 4.2 MB/s eta 0:00:06
#    ------ --------------------------------- 4.5/25.9 MB 4.2 MB/s eta 0:00:06
#    ------ --------------------------------- 4.5/25.9 MB 4.2 MB/s eta 0:00:06
#    ------ --------------------------------- 4.5/25.9 MB 4.2 MB/s eta 0:00:06
#    ------ --------------------------------- 4.5/25.9 MB 4.2 MB/s eta 0:00:06
#    ------ --------------------------------- 4.5/25.9 MB 4.2 MB/s eta 0:00:06
#    ------ --------------------------------- 4.5/25.9 MB 4.2 MB/s eta 0:00:06
#    ------ --------------------------------- 4.5/25.9 MB 4.2 MB/s eta 0:00:06
#    ------ --------------------------------- 4.5/25.9 MB 4.2 MB/s eta 0:00:06
#    ------ --------------------------------- 4.5/25.9 MB 4.2 MB/s eta 0:00:06
#    ------- -------------------------------- 4.8/25.9 MB 2.6 MB/s eta 0:00:09
#    ------- -------------------------------- 5.1/25.9 MB 2.7 MB/s eta 0:00:08
#    -------- ------------------------------- 5.4/25.9 MB 2.9 MB/s eta 0:00:08
#    --------- ------------------------------ 5.8/25.9 MB 3.0 MB/s eta 0:00:07
#    --------- ------------------------------ 6.3/25.9 MB 3.2 MB/s eta 0:00:07
#    ---------- ----------------------------- 6.9/25.9 MB 3.4 MB/s eta 0:00:06
#    ---------- ----------------------------- 6.9/25.9 MB 3.4 MB/s eta 0:00:06
#    ----------- ---------------------------- 7.2/25.9 MB 3.4 MB/s eta 0:00:06
#    ----------- ---------------------------- 7.6/25.9 MB 3.5 MB/s eta 0:00:06
#    ------------ --------------------------- 8.0/25.9 MB 3.6 MB/s eta 0:00:05
#    ------------ --------------------------- 8.4/25.9 MB 3.7 MB/s eta 0:00:05
#    ------------- -------------------------- 8.7/25.9 MB 3.8 MB/s eta 0:00:05
#    -------------- ------------------------- 9.2/25.9 MB 3.9 MB/s eta 0:00:05
#    -------------- ------------------------- 9.4/25.9 MB 4.0 MB/s eta 0:00:05
#    -------------- ------------------------- 9.4/25.9 MB 4.0 MB/s eta 0:00:05
#    -------------- ------------------------- 9.4/25.9 MB 4.0 MB/s eta 0:00:05
#    -------------- ------------------------- 9.4/25.9 MB 4.0 MB/s eta 0:00:05
#    -------------- ------------------------- 9.4/25.9 MB 4.0 MB/s eta 0:00:05
#    -------------- ------------------------- 9.4/25.9 MB 4.0 MB/s eta 0:00:05
#    -------------- ------------------------- 9.4/25.9 MB 4.0 MB/s eta 0:00:05
#    -------------- ------------------------- 9.6/25.9 MB 3.6 MB/s eta 0:00:05
#    --------------- ------------------------ 10.0/25.9 MB 3.7 MB/s eta 0:00:05
#    --------------- ------------------------ 10.2/25.9 MB 3.7 MB/s eta 0:00:05
#    ---------------- ----------------------- 10.5/25.9 MB 3.7 MB/s eta 0:00:05
#    ---------------- ----------------------- 10.9/25.9 MB 3.7 MB/s eta 0:00:05
#    ----------------- ---------------------- 11.1/25.9 MB 3.6 MB/s eta 0:00:05
#    ----------------- ---------------------- 11.4/25.9 MB 3.6 MB/s eta 0:00:05
#    ------------------ --------------------- 11.8/25.9 MB 3.6 MB/s eta 0:00:04
#    ------------------ --------------------- 11.8/25.9 MB 3.6 MB/s eta 0:00:04
#    ------------------ --------------------- 11.8/25.9 MB 3.6 MB/s eta 0:00:04
#    ------------------ --------------------- 11.8/25.9 MB 3.6 MB/s eta 0:00:04
#    ------------------ --------------------- 11.8/25.9 MB 3.6 MB/s eta 0:00:04
#    ------------------ --------------------- 11.8/25.9 MB 3.6 MB/s eta 0:00:04
#    ------------------ --------------------- 11.8/25.9 MB 3.6 MB/s eta 0:00:04
#    ------------------ --------------------- 11.8/25.9 MB 3.2 MB/s eta 0:00:05
#    ------------------ --------------------- 12.0/25.9 MB 3.2 MB/s eta 0:00:05
#    ------------------ --------------------- 12.1/25.9 MB 3.1 MB/s eta 0:00:05
#    ------------------ --------------------- 12.3/25.9 MB 4.0 MB/s eta 0:00:04
#    ------------------- -------------------- 12.4/25.9 MB 4.0 MB/s eta 0:00:04
#    ------------------- -------------------- 12.5/25.9 MB 3.9 MB/s eta 0:00:04
#    ------------------- -------------------- 12.7/25.9 MB 3.9 MB/s eta 0:00:04
#    ------------------- -------------------- 12.8/25.9 MB 3.8 MB/s eta 0:00:04
#    ------------------- -------------------- 12.9/25.9 MB 3.8 MB/s eta 0:00:04
#    -------------------- ------------------- 13.1/25.9 MB 3.7 MB/s eta 0:00:04
#    -------------------- ------------------- 13.1/25.9 MB 3.7 MB/s eta 0:00:04
#    -------------------- ------------------- 13.3/25.9 MB 3.6 MB/s eta 0:00:04
#    -------------------- ------------------- 13.3/25.9 MB 3.6 MB/s eta 0:00:04
#    -------------------- ------------------- 13.4/25.9 MB 3.5 MB/s eta 0:00:04
#    -------------------- ------------------- 13.4/25.9 MB 3.5 MB/s eta 0:00:04
#    -------------------- ------------------- 13.5/25.9 MB 3.4 MB/s eta 0:00:04
#    -------------------- ------------------- 13.5/25.9 MB 3.4 MB/s eta 0:00:04
#    --------------------- ------------------ 13.6/25.9 MB 3.3 MB/s eta 0:00:04
#    --------------------- ------------------ 13.6/25.9 MB 3.3 MB/s eta 0:00:04
#    --------------------- ------------------ 13.7/25.9 MB 3.2 MB/s eta 0:00:04
#    --------------------- ------------------ 13.7/25.9 MB 3.2 MB/s eta 0:00:04
#    --------------------- ------------------ 13.7/25.9 MB 3.2 MB/s eta 0:00:04
#    --------------------- ------------------ 13.8/25.9 MB 3.1 MB/s eta 0:00:04
#    --------------------- ------------------ 13.8/25.9 MB 3.1 MB/s eta 0:00:04
#    --------------------- ------------------ 13.9/25.9 MB 3.1 MB/s eta 0:00:04
#    --------------------- ------------------ 13.9/25.9 MB 3.0 MB/s eta 0:00:04
#    --------------------- ------------------ 14.0/25.9 MB 3.0 MB/s eta 0:00:04
#    --------------------- ------------------ 14.0/25.9 MB 3.0 MB/s eta 0:00:05
#    --------------------- ------------------ 14.0/25.9 MB 3.0 MB/s eta 0:00:05
#    --------------------- ------------------ 14.1/25.9 MB 2.9 MB/s eta 0:00:05
#    --------------------- ------------------ 14.1/25.9 MB 2.9 MB/s eta 0:00:05
#    --------------------- ------------------ 14.2/25.9 MB 2.8 MB/s eta 0:00:05
#    --------------------- ------------------ 14.2/25.9 MB 2.8 MB/s eta 0:00:05
#    --------------------- ------------------ 14.2/25.9 MB 2.8 MB/s eta 0:00:05
#    ---------------------- ----------------- 14.3/25.9 MB 2.7 MB/s eta 0:00:05
#    ---------------------- ----------------- 14.3/25.9 MB 2.7 MB/s eta 0:00:05
#    ---------------------- ----------------- 14.4/25.9 MB 2.7 MB/s eta 0:00:05
#    ---------------------- ----------------- 14.4/25.9 MB 2.7 MB/s eta 0:00:05
#    ---------------------- ----------------- 14.5/25.9 MB 2.6 MB/s eta 0:00:05
#    ---------------------- ----------------- 14.6/25.9 MB 2.6 MB/s eta 0:00:05
#    ---------------------- ----------------- 14.6/25.9 MB 2.6 MB/s eta 0:00:05
#    ---------------------- ----------------- 14.7/25.9 MB 3.1 MB/s eta 0:00:04
#    ---------------------- ----------------- 14.8/25.9 MB 3.1 MB/s eta 0:00:04
#    ----------------------- ---------------- 14.9/25.9 MB 3.1 MB/s eta 0:00:04
#    ----------------------- ---------------- 15.0/25.9 MB 3.0 MB/s eta 0:00:04
#    ----------------------- ---------------- 15.1/25.9 MB 3.0 MB/s eta 0:00:04
#    ----------------------- ---------------- 15.2/25.9 MB 3.0 MB/s eta 0:00:04
#    ----------------------- ---------------- 15.4/25.9 MB 3.0 MB/s eta 0:00:04
#    ------------------------ --------------- 15.6/25.9 MB 3.0 MB/s eta 0:00:04
#    ------------------------ --------------- 15.9/25.9 MB 3.0 MB/s eta 0:00:04
#    ------------------------- -------------- 16.2/25.9 MB 2.9 MB/s eta 0:00:04
#    ------------------------- -------------- 16.5/25.9 MB 2.9 MB/s eta 0:00:04
#    ------------------------- -------------- 16.6/25.9 MB 2.9 MB/s eta 0:00:04
#    ------------------------- -------------- 16.8/25.9 MB 2.9 MB/s eta 0:00:04
#    -------------------------- ------------- 16.9/25.9 MB 2.9 MB/s eta 0:00:04
#    -------------------------- ------------- 17.0/25.9 MB 2.8 MB/s eta 0:00:04
#    -------------------------- ------------- 17.1/25.9 MB 2.8 MB/s eta 0:00:04
#    -------------------------- ------------- 17.2/25.9 MB 2.8 MB/s eta 0:00:04
#    -------------------------- ------------- 17.2/25.9 MB 2.8 MB/s eta 0:00:04
#    --------------------------- ------------ 17.5/25.9 MB 2.8 MB/s eta 0:00:04
#    --------------------------- ------------ 17.6/25.9 MB 2.8 MB/s eta 0:00:03
#    --------------------------- ------------ 17.8/25.9 MB 2.8 MB/s eta 0:00:03
#    --------------------------- ------------ 17.9/25.9 MB 2.7 MB/s eta 0:00:03
#    --------------------------- ------------ 18.0/25.9 MB 2.7 MB/s eta 0:00:03
#    --------------------------- ------------ 18.0/25.9 MB 2.7 MB/s eta 0:00:03
#    --------------------------- ------------ 18.1/25.9 MB 2.7 MB/s eta 0:00:03
#    --------------------------- ------------ 18.1/25.9 MB 2.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.2/25.9 MB 2.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.3/25.9 MB 2.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.4/25.9 MB 2.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.4/25.9 MB 2.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.5/25.9 MB 2.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.7/25.9 MB 2.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 18.8/25.9 MB 2.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 18.9/25.9 MB 2.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 19.1/25.9 MB 2.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 19.2/25.9 MB 2.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 19.3/25.9 MB 2.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 19.4/25.9 MB 2.4 MB/s eta 0:00:03
#    ------------------------------ --------- 19.5/25.9 MB 2.4 MB/s eta 0:00:03
#    ------------------------------ --------- 19.8/25.9 MB 2.5 MB/s eta 0:00:03
#    ------------------------------ --------- 20.0/25.9 MB 2.5 MB/s eta 0:00:03
#    ------------------------------- -------- 20.4/25.9 MB 2.5 MB/s eta 0:00:03
#    ------------------------------- -------- 20.7/25.9 MB 2.5 MB/s eta 0:00:03
#    -------------------------------- ------- 20.9/25.9 MB 2.5 MB/s eta 0:00:02
#    -------------------------------- ------- 21.1/25.9 MB 2.5 MB/s eta 0:00:02
#    -------------------------------- ------- 21.3/25.9 MB 2.5 MB/s eta 0:00:02
#    --------------------------------- ------ 21.5/25.9 MB 2.5 MB/s eta 0:00:02
#    --------------------------------- ------ 21.7/25.9 MB 2.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 22.0/25.9 MB 2.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 22.2/25.9 MB 2.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 22.4/25.9 MB 2.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 22.6/25.9 MB 2.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 22.8/25.9 MB 2.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 23.1/25.9 MB 2.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 23.3/25.9 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 23.5/25.9 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 23.6/25.9 MB 2.9 MB/s eta 0:00:01
#    ------------------------------------ --- 23.8/25.9 MB 2.9 MB/s eta 0:00:01
#    ------------------------------------- -- 24.1/25.9 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------- -- 24.3/25.9 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 24.6/25.9 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 25.0/25.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  25.4/25.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  25.5/25.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  25.5/25.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  25.5/25.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  25.5/25.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  25.5/25.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  25.5/25.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  25.5/25.9 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  25.6/25.9 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  25.7/25.9 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  25.8/25.9 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 25.9/25.9 MB 3.6 MB/s eta 0:00:00
# Downloading safetensors-0.4.3-cp310-none-win_amd64.whl (287 kB)
#    ---------------------------------------- 0.0/287.4 kB ? eta -:--:--
#    --------------- ------------------------ 112.6/287.4 kB 3.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 204.8/287.4 kB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 287.4/287.4 kB 2.5 MB/s eta 0:00:00
# Downloading soundfile-0.12.1-py2.py3-none-win_amd64.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---- ----------------------------------- 0.1/1.0 MB 3.6 MB/s eta 0:00:01
#    ------------------ --------------------- 0.5/1.0 MB 5.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 0.7/1.0 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 0.9/1.0 MB 4.9 MB/s eta 0:00:01
#    -------------------------------------- - 1.0/1.0 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 4.3 MB/s eta 0:00:00
# Downloading tokenizers-0.19.1-cp310-none-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.2 MB 5.5 MB/s eta 0:00:01
#    ------ --------------------------------- 0.4/2.2 MB 4.7 MB/s eta 0:00:01
#    ------------- -------------------------- 0.8/2.2 MB 6.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.2/2.2 MB 7.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.5/2.2 MB 6.8 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.2 MB 6.6 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.2 MB 6.6 MB/s eta 0:00:01
#    ------------------------------------ --- 2.0/2.2 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 5.9 MB/s eta 0:00:00
# Downloading datasets-2.19.1-py3-none-any.whl (542 kB)
#    ---------------------------------------- 0.0/542.0 kB ? eta -:--:--
#    --------------------------- ------------ 378.9/542.0 kB 7.8 MB/s eta 0:00:01
#    ---------------------------------------- 542.0/542.0 kB 8.4 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ---------------------------------------- 0.0/134.8 kB ? eta -:--:--
#    ---------------------------------------- 134.8/134.8 kB 7.8 MB/s eta 0:00:00
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading xxhash-3.4.1-cp310-cp310-win_amd64.whl (29 kB)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml): started
#   Building wheel for transformers (pyproject.toml): finished with status 'done'
#   Created wheel for transformers: filename=transformers-4.41.0.dev0-py3-none-any.whl size=9055460 sha256=8003d92c9b9251d36b128efca19449e7f8ffaf5cc530153a8bf650a5d6de9608
#   Stored in directory: C:\Users\fyzan\AppData\Local\Temp\pip-ephem-wheel-cache-qbbl58qs\wheels\e7\9c\5b\e1a9c8007c343041e61cc484433d512ea9274272e3fcbe7c16
# Successfully built transformers
# Installing collected packages: xxhash, safetensors, pyarrow-hotfix, pyarrow, dill, soundfile, multiprocess, tokenizers, accelerate, transformers, datasets
#   Attempting uninstall: soundfile
#     Found existing installation: SoundFile 0.10.3.post1
#     Uninstalling SoundFile-0.10.3.post1:
#       Successfully uninstalled SoundFile-0.10.3.post1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.12.1
#     Uninstalling tokenizers-0.12.1:
#       Successfully uninstalled tokenizers-0.12.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.18.0
#     Uninstalling transformers-4.18.0:
#       Successfully uninstalled transformers-4.18.0
# Successfully installed accelerate-0.30.1 datasets-2.19.1 dill-0.3.8 multiprocess-0.70.16 pyarrow-16.1.0 pyarrow-hotfix-0.6 safetensors-0.4.3 soundfile-0.12.1 tokenizers-0.19.1 transformers-4.41.0.dev0 xxhash-3.4.1
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git 'C:\Users\fyzan\AppData\Local\Temp\pip-req-build-wngl1esl'

# %%
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
from datasets import load_dataset

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

model_id = "openai/whisper-large-v3"

model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
)
model.to(device)

processor = AutoProcessor.from_pretrained(model_id)

# %%
pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    max_new_tokens=128,
    chunk_length_s=30,
    batch_size=16,
    return_timestamps=True,
    torch_dtype=torch_dtype,
    device=device,
)

# %%
dataset = load_dataset("distil-whisper/librispeech_long", "clean", split="validation")
sample = dataset[0]["audio"]

# %%
sample = "ytaudio.wav"
result = pipe(sample, return_timestamps=True)
print(result["chunks"])
